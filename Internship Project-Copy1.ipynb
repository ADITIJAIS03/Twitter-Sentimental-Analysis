# %%
pip install nltk pandas textblob pandas-profiling wordcloud matplotlib ipython
# Out:
# Requirement already satisfied: nltk in c:\users\hp\anaconda3\lib\site-packages (3.8.1)
# Requirement already satisfied: pandas in c:\users\hp\anaconda3\lib\site-packages (1.5.3)
# Requirement already satisfied: textblob in c:\users\hp\anaconda3\lib\site-packages (0.17.1)
# Requirement already satisfied: pandas-profiling in c:\users\hp\anaconda3\lib\site-packages (3.2.0)
# Requirement already satisfied: wordcloud in c:\users\hp\anaconda3\lib\site-packages (1.9.2)
# Requirement already satisfied: matplotlib in c:\users\hp\anaconda3\lib\site-packages (3.7.1)
# Requirement already satisfied: ipython in c:\users\hp\anaconda3\lib\site-packages (8.12.0)
# Requirement already satisfied: click in c:\users\hp\anaconda3\lib\site-packages (from nltk) (8.0.4)
# Requirement already satisfied: joblib in c:\users\hp\anaconda3\lib\site-packages (from nltk) (1.1.1)
# Requirement already satisfied: regex>=2021.8.3 in c:\users\hp\anaconda3\lib\site-packages (from nltk) (2022.7.9)
# Requirement already satisfied: tqdm in c:\users\hp\anaconda3\lib\site-packages (from nltk) (4.65.0)
# Requirement already satisfied: python-dateutil>=2.8.1 in c:\users\hp\anaconda3\lib\site-packages (from pandas) (2.8.2)
# Requirement already satisfied: pytz>=2020.1 in c:\users\hp\anaconda3\lib\site-packages (from pandas) (2022.7)
# Requirement already satisfied: numpy>=1.21.0 in c:\users\hp\anaconda3\lib\site-packages (from pandas) (1.23.5)
# Requirement already satisfied: scipy>=1.4.1 in c:\users\hp\anaconda3\lib\site-packages (from pandas-profiling) (1.10.1)
# Requirement already satisfied: pydantic>=1.8.1 in c:\users\hp\anaconda3\lib\site-packages (from pandas-profiling) (1.10.12)
# Requirement already satisfied: PyYAML>=5.0.0 in c:\users\hp\anaconda3\lib\site-packages (from pandas-profiling) (6.0)
# Requirement already satisfied: jinja2>=2.11.1 in c:\users\hp\anaconda3\lib\site-packages (from pandas-profiling) (3.1.2)
# Requirement already satisfied: markupsafe~=2.1.1 in c:\users\hp\anaconda3\lib\site-packages (from pandas-profiling) (2.1.1)
# Collecting visions[type_image_path]==0.7.4 (from pandas-profiling)
#   Using cached visions-0.7.4-py3-none-any.whl (102 kB)
# Requirement already satisfied: htmlmin>=0.1.12 in c:\users\hp\anaconda3\lib\site-packages (from pandas-profiling) (0.1.12)
# Requirement already satisfied: missingno>=0.4.2 in c:\users\hp\anaconda3\lib\site-packages (from pandas-profiling) (0.5.2)
# Requirement already satisfied: phik>=0.11.1 in c:\users\hp\anaconda3\lib\site-packages (from pandas-profiling) (0.12.3)
# Requirement already satisfied: tangled-up-in-unicode==0.2.0 in c:\users\hp\anaconda3\lib\site-packages (from pandas-profiling) (0.2.0)
# Requirement already satisfied: requests>=2.24.0 in c:\users\hp\anaconda3\lib\site-packages (from pandas-profiling) (2.31.0)
# Requirement already satisfied: seaborn>=0.10.1 in c:\users\hp\anaconda3\lib\site-packages (from pandas-profiling) (0.12.2)
# Requirement already satisfied: multimethod>=1.4 in c:\users\hp\anaconda3\lib\site-packages (from pandas-profiling) (1.9.1)
# Requirement already satisfied: attrs>=19.3.0 in c:\users\hp\anaconda3\lib\site-packages (from visions[type_image_path]==0.7.4->pandas-profiling) (22.1.0)
# Requirement already satisfied: networkx>=2.4 in c:\users\hp\anaconda3\lib\site-packages (from visions[type_image_path]==0.7.4->pandas-profiling) (3.1)
# Requirement already satisfied: imagehash in c:\users\hp\anaconda3\lib\site-packages (from visions[type_image_path]==0.7.4->pandas-profiling) (4.3.1)
# Requirement already satisfied: Pillow in c:\users\hp\anaconda3\lib\site-packages (from visions[type_image_path]==0.7.4->pandas-profiling) (9.4.0)
# Requirement already satisfied: contourpy>=1.0.1 in c:\users\hp\anaconda3\lib\site-packages (from matplotlib) (1.0.5)
# Requirement already satisfied: cycler>=0.10 in c:\users\hp\anaconda3\lib\site-packages (from matplotlib) (0.11.0)
# Requirement already satisfied: fonttools>=4.22.0 in c:\users\hp\anaconda3\lib\site-packages (from matplotlib) (4.25.0)
# Requirement already satisfied: kiwisolver>=1.0.1 in c:\users\hp\anaconda3\lib\site-packages (from matplotlib) (1.4.4)
# Requirement already satisfied: packaging>=20.0 in c:\users\hp\anaconda3\lib\site-packages (from matplotlib) (23.0)
# Requirement already satisfied: pyparsing>=2.3.1 in c:\users\hp\anaconda3\lib\site-packages (from matplotlib) (3.0.9)
# Requirement already satisfied: backcall in c:\users\hp\anaconda3\lib\site-packages (from ipython) (0.2.0)
# Requirement already satisfied: decorator in c:\users\hp\anaconda3\lib\site-packages (from ipython) (5.1.1)
# Requirement already satisfied: jedi>=0.16 in c:\users\hp\anaconda3\lib\site-packages (from ipython) (0.18.1)
# Requirement already satisfied: matplotlib-inline in c:\users\hp\anaconda3\lib\site-packages (from ipython) (0.1.6)
# Requirement already satisfied: pickleshare in c:\users\hp\anaconda3\lib\site-packages (from ipython) (0.7.5)
# Requirement already satisfied: prompt-toolkit!=3.0.37,<3.1.0,>=3.0.30 in c:\users\hp\anaconda3\lib\site-packages (from ipython) (3.0.36)
# Requirement already satisfied: pygments>=2.4.0 in c:\users\hp\anaconda3\lib\site-packages (from ipython) (2.15.1)
# Requirement already satisfied: stack-data in c:\users\hp\anaconda3\lib\site-packages (from ipython) (0.2.0)
# Requirement already satisfied: traitlets>=5 in c:\users\hp\anaconda3\lib\site-packages (from ipython) (5.7.1)
# Requirement already satisfied: colorama in c:\users\hp\anaconda3\lib\site-packages (from ipython) (0.4.6)
# Requirement already satisfied: parso<0.9.0,>=0.8.0 in c:\users\hp\anaconda3\lib\site-packages (from jedi>=0.16->ipython) (0.8.3)
# Requirement already satisfied: wcwidth in c:\users\hp\anaconda3\lib\site-packages (from prompt-toolkit!=3.0.37,<3.1.0,>=3.0.30->ipython) (0.2.5)
# Requirement already satisfied: typing-extensions>=4.2.0 in c:\users\hp\anaconda3\lib\site-packages (from pydantic>=1.8.1->pandas-profiling) (4.7.1)
# Requirement already satisfied: six>=1.5 in c:\users\hp\anaconda3\lib\site-packages (from python-dateutil>=2.8.1->pandas) (1.16.0)
# Requirement already satisfied: charset-normalizer<4,>=2 in c:\users\hp\anaconda3\lib\site-packages (from requests>=2.24.0->pandas-profiling) (2.0.4)
# Requirement already satisfied: idna<4,>=2.5 in c:\users\hp\anaconda3\lib\site-packages (from requests>=2.24.0->pandas-profiling) (3.4)
# Requirement already satisfied: urllib3<3,>=1.21.1 in c:\users\hp\anaconda3\lib\site-packages (from requests>=2.24.0->pandas-profiling) (1.26.16)
# Requirement already satisfied: certifi>=2017.4.17 in c:\users\hp\anaconda3\lib\site-packages (from requests>=2.24.0->pandas-profiling) (2023.7.22)
# Requirement already satisfied: executing in c:\users\hp\anaconda3\lib\site-packages (from stack-data->ipython) (0.8.3)
# Requirement already satisfied: asttokens in c:\users\hp\anaconda3\lib\site-packages (from stack-data->ipython) (2.0.5)
# Requirement already satisfied: pure-eval in c:\users\hp\anaconda3\lib\site-packages (from stack-data->ipython) (0.2.2)
# Requirement already satisfied: PyWavelets in c:\users\hp\anaconda3\lib\site-packages (from imagehash->visions[type_image_path]==0.7.4->pandas-profiling) (1.4.1)
# Installing collected packages: visions
#   Attempting uninstall: visions
#     Found existing installation: visions 0.7.5
#     Uninstalling visions-0.7.5:
#       Successfully uninstalled visions-0.7.5
# Successfully installed visions-0.7.4
# Note: you may need to restart the kernel to use updated packages.
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# ydata-profiling 4.5.1 requires visions[type_image_path]==0.7.5, but you have visions 0.7.4 which is incompatible.

# %%
pip install --upgrade pandas-profiling
# Out:
# Requirement already satisfied: pandas-profiling in c:\users\hp\anaconda3\lib\site-packages (3.2.0)
# Requirement already satisfied: joblib~=1.1.0 in c:\users\hp\anaconda3\lib\site-packages (from pandas-profiling) (1.1.1)
# Requirement already satisfied: scipy>=1.4.1 in c:\users\hp\anaconda3\lib\site-packages (from pandas-profiling) (1.10.1)
# Requirement already satisfied: pandas!=1.0.0,!=1.0.1,!=1.0.2,!=1.1.0,>=0.25.3 in c:\users\hp\anaconda3\lib\site-packages (from pandas-profiling) (1.5.3)
# Requirement already satisfied: matplotlib>=3.2.0 in c:\users\hp\anaconda3\lib\site-packages (from pandas-profiling) (3.7.1)
# Requirement already satisfied: pydantic>=1.8.1 in c:\users\hp\anaconda3\lib\site-packages (from pandas-profiling) (1.10.12)
# Requirement already satisfied: PyYAML>=5.0.0 in c:\users\hp\anaconda3\lib\site-packages (from pandas-profiling) (6.0)
# Requirement already satisfied: jinja2>=2.11.1 in c:\users\hp\anaconda3\lib\site-packages (from pandas-profiling) (3.1.2)
# Requirement already satisfied: markupsafe~=2.1.1 in c:\users\hp\anaconda3\lib\site-packages (from pandas-profiling) (2.1.1)
# Requirement already satisfied: visions[type_image_path]==0.7.4 in c:\users\hp\anaconda3\lib\site-packages (from pandas-profiling) (0.7.4)
# Requirement already satisfied: numpy>=1.16.0 in c:\users\hp\anaconda3\lib\site-packages (from pandas-profiling) (1.23.5)
# Requirement already satisfied: htmlmin>=0.1.12 in c:\users\hp\anaconda3\lib\site-packages (from pandas-profiling) (0.1.12)
# Requirement already satisfied: missingno>=0.4.2 in c:\users\hp\anaconda3\lib\site-packages (from pandas-profiling) (0.5.2)
# Requirement already satisfied: phik>=0.11.1 in c:\users\hp\anaconda3\lib\site-packages (from pandas-profiling) (0.12.3)
# Requirement already satisfied: tangled-up-in-unicode==0.2.0 in c:\users\hp\anaconda3\lib\site-packages (from pandas-profiling) (0.2.0)
# Requirement already satisfied: requests>=2.24.0 in c:\users\hp\anaconda3\lib\site-packages (from pandas-profiling) (2.31.0)
# Requirement already satisfied: tqdm>=4.48.2 in c:\users\hp\anaconda3\lib\site-packages (from pandas-profiling) (4.65.0)
# Requirement already satisfied: seaborn>=0.10.1 in c:\users\hp\anaconda3\lib\site-packages (from pandas-profiling) (0.12.2)
# Requirement already satisfied: multimethod>=1.4 in c:\users\hp\anaconda3\lib\site-packages (from pandas-profiling) (1.9.1)
# Requirement already satisfied: attrs>=19.3.0 in c:\users\hp\anaconda3\lib\site-packages (from visions[type_image_path]==0.7.4->pandas-profiling) (22.1.0)
# Requirement already satisfied: networkx>=2.4 in c:\users\hp\anaconda3\lib\site-packages (from visions[type_image_path]==0.7.4->pandas-profiling) (3.1)
# Requirement already satisfied: imagehash in c:\users\hp\anaconda3\lib\site-packages (from visions[type_image_path]==0.7.4->pandas-profiling) (4.3.1)
# Requirement already satisfied: Pillow in c:\users\hp\anaconda3\lib\site-packages (from visions[type_image_path]==0.7.4->pandas-profiling) (9.4.0)
# Requirement already satisfied: contourpy>=1.0.1 in c:\users\hp\anaconda3\lib\site-packages (from matplotlib>=3.2.0->pandas-profiling) (1.0.5)
# Requirement already satisfied: cycler>=0.10 in c:\users\hp\anaconda3\lib\site-packages (from matplotlib>=3.2.0->pandas-profiling) (0.11.0)
# Requirement already satisfied: fonttools>=4.22.0 in c:\users\hp\anaconda3\lib\site-packages (from matplotlib>=3.2.0->pandas-profiling) (4.25.0)
# Requirement already satisfied: kiwisolver>=1.0.1 in c:\users\hp\anaconda3\lib\site-packages (from matplotlib>=3.2.0->pandas-profiling) (1.4.4)
# Requirement already satisfied: packaging>=20.0 in c:\users\hp\anaconda3\lib\site-packages (from matplotlib>=3.2.0->pandas-profiling) (23.0)
# Requirement already satisfied: pyparsing>=2.3.1 in c:\users\hp\anaconda3\lib\site-packages (from matplotlib>=3.2.0->pandas-profiling) (3.0.9)
# Requirement already satisfied: python-dateutil>=2.7 in c:\users\hp\anaconda3\lib\site-packages (from matplotlib>=3.2.0->pandas-profiling) (2.8.2)
# Requirement already satisfied: pytz>=2020.1 in c:\users\hp\anaconda3\lib\site-packages (from pandas!=1.0.0,!=1.0.1,!=1.0.2,!=1.1.0,>=0.25.3->pandas-profiling) (2022.7)
# Requirement already satisfied: typing-extensions>=4.2.0 in c:\users\hp\anaconda3\lib\site-packages (from pydantic>=1.8.1->pandas-profiling) (4.7.1)
# Requirement already satisfied: charset-normalizer<4,>=2 in c:\users\hp\anaconda3\lib\site-packages (from requests>=2.24.0->pandas-profiling) (2.0.4)
# Requirement already satisfied: idna<4,>=2.5 in c:\users\hp\anaconda3\lib\site-packages (from requests>=2.24.0->pandas-profiling) (3.4)
# Requirement already satisfied: urllib3<3,>=1.21.1 in c:\users\hp\anaconda3\lib\site-packages (from requests>=2.24.0->pandas-profiling) (1.26.16)
# Requirement already satisfied: certifi>=2017.4.17 in c:\users\hp\anaconda3\lib\site-packages (from requests>=2.24.0->pandas-profiling) (2023.7.22)
# Requirement already satisfied: colorama in c:\users\hp\anaconda3\lib\site-packages (from tqdm>=4.48.2->pandas-profiling) (0.4.6)
# Requirement already satisfied: six>=1.5 in c:\users\hp\anaconda3\lib\site-packages (from python-dateutil>=2.7->matplotlib>=3.2.0->pandas-profiling) (1.16.0)
# Requirement already satisfied: PyWavelets in c:\users\hp\anaconda3\lib\site-packages (from imagehash->visions[type_image_path]==0.7.4->pandas-profiling) (1.4.1)
# Note: you may need to restart the kernel to use updated packages.

# %%
pip install ydata_profiling
# Out:
# Requirement already satisfied: ydata_profiling in c:\users\hp\anaconda3\lib\site-packages (4.5.1)
# Requirement already satisfied: scipy<1.12,>=1.4.1 in c:\users\hp\anaconda3\lib\site-packages (from ydata_profiling) (1.10.1)
# Requirement already satisfied: pandas!=1.4.0,<2.1,>1.1 in c:\users\hp\anaconda3\lib\site-packages (from ydata_profiling) (1.5.3)
# Requirement already satisfied: matplotlib<4,>=3.2 in c:\users\hp\anaconda3\lib\site-packages (from ydata_profiling) (3.7.1)
# Requirement already satisfied: pydantic<2,>=1.8.1 in c:\users\hp\anaconda3\lib\site-packages (from ydata_profiling) (1.10.12)
# Requirement already satisfied: PyYAML<6.1,>=5.0.0 in c:\users\hp\anaconda3\lib\site-packages (from ydata_profiling) (6.0)
# Requirement already satisfied: jinja2<3.2,>=2.11.1 in c:\users\hp\anaconda3\lib\site-packages (from ydata_profiling) (3.1.2)
# Collecting visions[type_image_path]==0.7.5 (from ydata_profiling)
#   Using cached visions-0.7.5-py3-none-any.whl (102 kB)
# Requirement already satisfied: numpy<1.24,>=1.16.0 in c:\users\hp\anaconda3\lib\site-packages (from ydata_profiling) (1.23.5)
# Requirement already satisfied: htmlmin==0.1.12 in c:\users\hp\anaconda3\lib\site-packages (from ydata_profiling) (0.1.12)
# Requirement already satisfied: phik<0.13,>=0.11.1 in c:\users\hp\anaconda3\lib\site-packages (from ydata_profiling) (0.12.3)
# Requirement already satisfied: requests<3,>=2.24.0 in c:\users\hp\anaconda3\lib\site-packages (from ydata_profiling) (2.31.0)
# Requirement already satisfied: tqdm<5,>=4.48.2 in c:\users\hp\anaconda3\lib\site-packages (from ydata_profiling) (4.65.0)
# Requirement already satisfied: seaborn<0.13,>=0.10.1 in c:\users\hp\anaconda3\lib\site-packages (from ydata_profiling) (0.12.2)
# Requirement already satisfied: multimethod<2,>=1.4 in c:\users\hp\anaconda3\lib\site-packages (from ydata_profiling) (1.9.1)
# Requirement already satisfied: statsmodels<1,>=0.13.2 in c:\users\hp\anaconda3\lib\site-packages (from ydata_profiling) (0.14.0)
# Requirement already satisfied: typeguard<3,>=2.13.2 in c:\users\hp\anaconda3\lib\site-packages (from ydata_profiling) (2.13.3)
# Requirement already satisfied: imagehash==4.3.1 in c:\users\hp\anaconda3\lib\site-packages (from ydata_profiling) (4.3.1)
# Requirement already satisfied: wordcloud>=1.9.1 in c:\users\hp\anaconda3\lib\site-packages (from ydata_profiling) (1.9.2)
# Requirement already satisfied: dacite>=1.8 in c:\users\hp\anaconda3\lib\site-packages (from ydata_profiling) (1.8.1)
# Requirement already satisfied: PyWavelets in c:\users\hp\anaconda3\lib\site-packages (from imagehash==4.3.1->ydata_profiling) (1.4.1)
# Requirement already satisfied: pillow in c:\users\hp\anaconda3\lib\site-packages (from imagehash==4.3.1->ydata_profiling) (9.4.0)
# Requirement already satisfied: attrs>=19.3.0 in c:\users\hp\anaconda3\lib\site-packages (from visions[type_image_path]==0.7.5->ydata_profiling) (22.1.0)
# Requirement already satisfied: networkx>=2.4 in c:\users\hp\anaconda3\lib\site-packages (from visions[type_image_path]==0.7.5->ydata_profiling) (3.1)
# Requirement already satisfied: tangled-up-in-unicode>=0.0.4 in c:\users\hp\anaconda3\lib\site-packages (from visions[type_image_path]==0.7.5->ydata_profiling) (0.2.0)
# Requirement already satisfied: MarkupSafe>=2.0 in c:\users\hp\anaconda3\lib\site-packages (from jinja2<3.2,>=2.11.1->ydata_profiling) (2.1.1)
# Requirement already satisfied: contourpy>=1.0.1 in c:\users\hp\anaconda3\lib\site-packages (from matplotlib<4,>=3.2->ydata_profiling) (1.0.5)
# Requirement already satisfied: cycler>=0.10 in c:\users\hp\anaconda3\lib\site-packages (from matplotlib<4,>=3.2->ydata_profiling) (0.11.0)
# Requirement already satisfied: fonttools>=4.22.0 in c:\users\hp\anaconda3\lib\site-packages (from matplotlib<4,>=3.2->ydata_profiling) (4.25.0)
# Requirement already satisfied: kiwisolver>=1.0.1 in c:\users\hp\anaconda3\lib\site-packages (from matplotlib<4,>=3.2->ydata_profiling) (1.4.4)
# Requirement already satisfied: packaging>=20.0 in c:\users\hp\anaconda3\lib\site-packages (from matplotlib<4,>=3.2->ydata_profiling) (23.0)
# Requirement already satisfied: pyparsing>=2.3.1 in c:\users\hp\anaconda3\lib\site-packages (from matplotlib<4,>=3.2->ydata_profiling) (3.0.9)
# Requirement already satisfied: python-dateutil>=2.7 in c:\users\hp\anaconda3\lib\site-packages (from matplotlib<4,>=3.2->ydata_profiling) (2.8.2)
# Requirement already satisfied: pytz>=2020.1 in c:\users\hp\anaconda3\lib\site-packages (from pandas!=1.4.0,<2.1,>1.1->ydata_profiling) (2022.7)
# Requirement already satisfied: joblib>=0.14.1 in c:\users\hp\anaconda3\lib\site-packages (from phik<0.13,>=0.11.1->ydata_profiling) (1.1.1)
# Requirement already satisfied: typing-extensions>=4.2.0 in c:\users\hp\anaconda3\lib\site-packages (from pydantic<2,>=1.8.1->ydata_profiling) (4.7.1)
# Requirement already satisfied: charset-normalizer<4,>=2 in c:\users\hp\anaconda3\lib\site-packages (from requests<3,>=2.24.0->ydata_profiling) (2.0.4)
# Requirement already satisfied: idna<4,>=2.5 in c:\users\hp\anaconda3\lib\site-packages (from requests<3,>=2.24.0->ydata_profiling) (3.4)
# Requirement already satisfied: urllib3<3,>=1.21.1 in c:\users\hp\anaconda3\lib\site-packages (from requests<3,>=2.24.0->ydata_profiling) (1.26.16)
# Requirement already satisfied: certifi>=2017.4.17 in c:\users\hp\anaconda3\lib\site-packages (from requests<3,>=2.24.0->ydata_profiling) (2023.7.22)
# Requirement already satisfied: patsy>=0.5.2 in c:\users\hp\anaconda3\lib\site-packages (from statsmodels<1,>=0.13.2->ydata_profiling) (0.5.3)
# Requirement already satisfied: colorama in c:\users\hp\anaconda3\lib\site-packages (from tqdm<5,>=4.48.2->ydata_profiling) (0.4.6)
# Requirement already satisfied: six in c:\users\hp\anaconda3\lib\site-packages (from patsy>=0.5.2->statsmodels<1,>=0.13.2->ydata_profiling) (1.16.0)
# Installing collected packages: visions
#   Attempting uninstall: visions
#     Found existing installation: visions 0.7.4
#     Uninstalling visions-0.7.4:
#       Successfully uninstalled visions-0.7.4
# Successfully installed visions-0.7.5
# Note: you may need to restart the kernel to use updated packages.
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# pandas-profiling 3.2.0 requires visions[type_image_path]==0.7.4, but you have visions 0.7.5 which is incompatible.

# %%
import nltk
import pandas as pd
from textblob import TextBlob
from pandas_profiling import ProfileReport
from wordcloud import WordCloud
import matplotlib.pyplot as plt
from IPython.display import HTML, display, Image

# Set Matplotlib backend to display inline in the notebook
# %matplotlib inline

# Download NLTK data (if not already downloaded)
nltk.download("punkt")

# Load the CSV dataset (replace 'covid19_tweets.csv' with your file path)
df = pd.read_csv('covid19_tweets.csv')

# Specify the name of the column containing the text to analyze
text_column = 'text'  # Replace 'text' with the actual column name

def analyze_sentiment(text):
    analysis = TextBlob(text)
    # Sentiment polarity ranges from -1 (negative) to 1 (positive)
    return analysis.sentiment.polarity

# Sentiment Analysis
max_rows = 500
row_count = 0
neutral_sentiments= []
positive_sentiments = []
negative_sentiments = []


for index, row in df.iterrows():
    if row_count >= max_rows:
        break  # Exit the loop after processing 200 rows

    text = row[text_column]

    polarity = analyze_sentiment(text)

    if polarity > 0:
        sentiment = "Positive"
        positive_sentiments.append(row)
    elif polarity < 0:
        sentiment = "Negative"
        negative_sentiments.append(row)
    elif polarity == 0:
        sentiment = "Neutral"
        neutral_sentiments.append(row)
        

    print(f"Row {index + 1}: '{text}'")
    print(f"Sentiment: {sentiment}")
    print(f"Polarity: {polarity}\n")

    row_count += 1

# Create DataFrames containing rows with positive and negative sentiments
df_positive_sentiments = pd.DataFrame(positive_sentiments)
df_negative_sentiments = pd.DataFrame(negative_sentiments)

# Data Profiling for positive sentiments
profile_positive = ProfileReport(df_positive_sentiments)
profile_positive.to_file(output_file="Positive_Sentiments_Profile_Report.html")

# Data Profiling for negative sentiments
profile_negative = ProfileReport(df_negative_sentiments)
profile_negative.to_file(output_file="Negative_Sentiments_Profile_Report.html")

# Create and display the Word Clouds for positive and negative sentiments
positive_text = " ".join(df_positive_sentiments[text_column].tolist())
negative_text = " ".join(df_negative_sentiments[text_column].tolist())

# Word Cloud for Positive Sentiments
wordcloud_positive = WordCloud(width=800, height=400, background_color='white').generate(positive_text)
plt.figure(figsize=(10, 5))
plt.imshow(wordcloud_positive, interpolation='bilinear')
plt.axis("off")
plt.title("Word Cloud for Positive Sentiments")
plt.show()

# Word Cloud for Negative Sentiments
wordcloud_negative = WordCloud(width=800, height=400, background_color='white').generate(negative_text)
plt.figure(figsize=(10, 5))
plt.imshow(wordcloud_negative, interpolation='bilinear')
plt.axis("off")
plt.title("Word Cloud for Negative Sentiments")
plt.show()

# Save the Word Clouds as image files and display them
wordcloud_positive.to_file("positive_wordcloud.png")
wordcloud_negative.to_file("negative_wordcloud.png")
# Out:
# C:\Users\HP\anaconda3\Lib\site-packages\numba\core\decorators.py:262: NumbaDeprecationWarning: numba.generated_jit is deprecated. Please see the documentation at: https://numba.readthedocs.io/en/stable/reference/deprecation.html#deprecation-of-generated-jit for more information and advice on a suitable replacement.
#   warnings.warn(msg, NumbaDeprecationWarning)
# C:\Users\HP\anaconda3\Lib\site-packages\visions\backends\shared\nan_handling.py:50: NumbaDeprecationWarning: The 'nopython' keyword argument was not supplied to the 'numba.jit' decorator. The implicit default value for this argument is currently False, but it will be changed to True in Numba 0.59.0. See https://numba.readthedocs.io/en/stable/reference/deprecation.html#deprecation-of-object-mode-fall-back-behaviour-when-using-jit for details.
#   @nb.jit
# C:\Users\HP\AppData\Local\Temp\ipykernel_16804\1865918533.py:4: DeprecationWarning: `import pandas_profiling` is going to be deprecated by April 1st. Please use `import ydata_profiling` instead.
#   from pandas_profiling import ProfileReport
# [nltk_data] Downloading package punkt to
# [nltk_data]     C:\Users\HP\AppData\Roaming\nltk_data...
# [nltk_data]   Package punkt is already up-to-date!
# Row 1: 'If I smelled the scent of hand sanitizers today on someone in the past, I would think they were so intoxicated that… https://t.co/QZvYbrOgb0'
# Sentiment: Negative
# Polarity: -0.25
#
# Row 2: 'Hey @Yankees @YankeesPR and @MLB - wouldn't it have made more sense to have the players pay their respects to the A… https://t.co/1QvW0zgyPu'
# Sentiment: Positive
# Polarity: 0.5
#
# Row 3: '@diane3443 @wdunlap @realDonaldTrump Trump never once claimed #COVID19 was a hoax. We all claim that this effort to… https://t.co/Jkk8vHWHb3'
# Sentiment: Neutral
# Polarity: 0.0
#
# Row 4: '@brookbanktv The one gift #COVID19 has give me is an appreciation for the simple things that were always around me… https://t.co/Z0pOAlFXcW'
# Sentiment: Neutral
# Polarity: 0.0
#
# Row 5: '25 July : Media Bulletin on Novel #CoronaVirusUpdates #COVID19
# @kansalrohit69 @DrSyedSehrish @airnewsalerts @ANI… https://t.co/MN0EEcsJHh'
# Sentiment: Neutral
# Polarity: 0.0
#
# Row 6: '#coronavirus #covid19 deaths continue to rise. It's almost  as bad as it ever was.  Politicians and businesses want… https://t.co/hXMHooXX2C'
# Sentiment: Negative
# Polarity: -0.6999999999999998
#
# Row 7: 'How #COVID19 Will Change Work in General (and recruiting, specifically) via/ @ProactiveTalent #Recruiting… https://t.co/bjZxzGPMbK'
# Sentiment: Positive
# Polarity: 0.05000000000000002
#
# Row 8: 'You now have to wear face coverings when out shopping - this includes a visit to your local Community Pharmacy… https://t.co/OSu5Q4kdd7'
# Sentiment: Neutral
# Polarity: 0.0
#
# Row 9: 'Praying for good health and recovery of @ChouhanShivraj .
# #covid19
# #covidPositive'
# Sentiment: Positive
# Polarity: 0.7
#
# Row 10: 'POPE AS GOD - Prophet Sadhu Sundar Selvaraj. Watch here at https://t.co/7X5RTyKVji
#
# #HurricaneHanna #COVID19… https://t.co/06dZcGUnwL'
# Sentiment: Neutral
# Polarity: 0.0
#
# Row 11: '49K+ Covid19 cases still no response from
# @cbseindia29 @HRDMinistry @DrRPNishank.Please cancel the compartment exa… https://t.co/kV2ZKmumu1'
# Sentiment: Neutral
# Polarity: 0.0
#
# Row 12: 'Order here: https://t.co/4NUrGX6EmA
#
# #logo #graphicdesigner #logodesign #logodesinger #icon  #minimalist #Abstract… https://t.co/0yPMoGqi9s'
# Sentiment: Neutral
# Polarity: 0.0
#
# Row 13: '👋🏻@PattyHajdu @NavdeepSBains — no one will be safe from #COVID19 until everyone is safe. Will you commit to ensure… https://t.co/aWCJo6eKvC'
# Sentiment: Positive
# Polarity: 0.5
#
# Row 14: 'Let's all protect ourselves from #COVID19.
# It's real and the numbers are climbing up fast in the Continent.
# Let's n… https://t.co/byMSfxltrw'
# Sentiment: Positive
# Polarity: 0.2
#
# Row 15: 'Rajasthan Government today started a Plasma Bank at Sawai Man Singh Hospital in Jaipur for treatment of COVID-19 pa… https://t.co/cwfCcWyaDA'
# Sentiment: Neutral
# Polarity: 0.0
#
# Row 16: 'Nagaland police on Covid-19 Awareness at City Tower Junction Dimapur.
#
# #Covid19 #keepsocialdistance… https://t.co/WOvFMqhuEO'
# Sentiment: Neutral
# Polarity: 0.0
#
# Row 17: 'July 25 #COVID19 update
# #TamilNadu - 6988
# Discharge- 7758
# People tested - 61729
# Actice cases - 52273
# #chennai - 1329'
# Sentiment: Neutral
# Polarity: 0.0
#
# Row 18: 'Second wave of #COVID19 in Flanders..back to more #homework again... https://t.co/9swImZACMN'
# Sentiment: Positive
# Polarity: 0.25
#
# Row 19: 'It is during our darkest moments that we must focus to see the #light.~Aristotle
# https://t.co/YLlS4Kj85c… https://t.co/tFJB7l1Kaw'
# Sentiment: Neutral
# Polarity: 0.0
#
# Row 20: 'COVID Update: The infection rate in Florida is following the natural curve that experts predicted if the initial cu… https://t.co/hmEwE747WK'
# Sentiment: Positive
# Polarity: 0.03333333333333333
#
# Row 21: '@EvanAKilgore @realDonaldTrump Good Patriots!
# Call to Volunteer to be an Election Judge.
# Polls cannot open without… https://t.co/qA3mA4zedZ'
# Sentiment: Positive
# Polarity: 0.4375
#
# Row 22: 'Coronavirus - South Africa: COVID-19 update for South Africa (24 July 2020) @nicd_sa @MoetiTshidi @WHOAFRO… https://t.co/WQzAdkpXC5'
# Sentiment: Neutral
# Polarity: 0.0
#
# Row 23: '@JimBnntt Your image doesn't list a source, but I'd be careful with overall "risk of dying" statistics related to… https://t.co/GRjVq8vYMy'
# Sentiment: Negative
# Polarity: -0.03333333333333333
#
# Row 24: 'The first comprehensive review of #WASH &amp; #COVID19.
#
# Analysis: key ways in which WASH can help reduce transmission… https://t.co/eCsfDmo9b4'
# Sentiment: Positive
# Polarity: 0.125
#
# Row 25: 'Holy water in times of #COVID19 https://t.co/YaZ49yxL27'
# Sentiment: Neutral
# Polarity: 0.0
#
# Row 26: '#Kolar
# Need #Blood Type :  B-positive
# At : Jalappa Hospital
# Blood Component : Need Plasma from B+ve #COVID19 recove… https://t.co/XtgxULc02Z'
# Sentiment: Neutral
# Polarity: 0.0
#
# Row 27: 'Our Munitions Response Team in #BosniaandHerzegovina modified ops and adopted masks, disinfectants, and sanitizers… https://t.co/lMbKXlw1wQ'
# Sentiment: Neutral
# Polarity: 0.0
#
# Row 28: 'I can imagine the same people profiting off the human suffering of #COVID19 will be studying these maps to make 207… https://t.co/NElsmGju2H'
# Sentiment: Neutral
# Polarity: 0.0
#
# Row 29: '#TNCoronaUpdate
#
# #TN crosses 2 lakh mark and 1,50,055 ppp has recovered so far.
#
# #COVID19 positive today 6988/total… https://t.co/QdJkpcc7qv'
# Sentiment: Positive
# Polarity: 0.16363636363636364
#
# Row 30: '@ratasjuri TAX Reform
#
# Tax-free minimum:
# For a company of five hundred thousand euros per year.
#
# Tax-free minimum:… https://t.co/gD0Q6ujjbl'
# Sentiment: Neutral
# Polarity: 0.0
#
# Row 31: '#FEMA acknowledges #PuertoRico lacks rebuilt homes and a hospital to survive #COVID19  https://t.co/PLXqKc5K5d'
# Sentiment: Neutral
# Polarity: 0.0
#
# Row 32: 'Actor @VishalKOfficial and his father Mr.G.K.Reddy tested positive for #Covid19 15/20 days back..
#
# While #Vishal 's… https://t.co/V5Lo8NRLWY'
# Sentiment: Positive
# Polarity: 0.11363636363636363
#
# Row 33: 'An update on the total #covid19 cases, recoveries, and deaths reported in countries in #Africa.  See the total numb… https://t.co/eqCJ3EhwRi'
# Sentiment: Neutral
# Polarity: 0.0
#
# Row 34: '@unionwill @megawedgy @jjhorgan “Regarding the community outbreak of #COVID19 on Haida Gwaii: 13 cases (one recover… https://t.co/rJzuY60qY7'
# Sentiment: Neutral
# Polarity: 0.0
#
# Row 35: 'A safe place to visit? Here is what our guests said, "The hotel were meticulous in applying hand sanitation and als… https://t.co/PVCji8s1Eg'
# Sentiment: Positive
# Polarity: 0.5
#
# Row 36: 'Our CEO @RamneekHH live with @SASCO_Jikelele WSU talking about, “The effects of Covid-19 on students”.… https://t.co/VMN2LxHAds'
# Sentiment: Positive
# Polarity: 0.13636363636363635
#
# Row 37: '@NicoleKowalski5 @chrisdameanor19 I'm feeling a little anxious because #COVID19 seems to have detracted everyone's… https://t.co/A3mHdXamLg'
# Sentiment: Negative
# Polarity: -0.21875
#
# Row 38: 'Actionables for a healthy recovery from #COVID19 #climate  https://t.co/crGlKZOz5Z'
# Sentiment: Positive
# Polarity: 0.5
#
# Row 39: '@jfoster2019 @bbclaurak Well #BorisJohnson might have understood more if he hadn't missed #5COBRA meeting #Five
# In… https://t.co/mQPAgCYGn2'
# Sentiment: Positive
# Polarity: 0.5
#
# Row 40: 'We released two new #COVID19 podcast episodes this week:
# -Technology Platforms Used to Conduct Telehealth Visits
# -C… https://t.co/G94VeYVCzk'
# Sentiment: Positive
# Polarity: 0.13636363636363635
#
# Row 41: '#PlayYourPart in the fight against #COVID19 . Each one of us can make a difference in containing the spread, lets… https://t.co/fRzLgrS8Qf'
# Sentiment: Neutral
# Polarity: 0.0
#
# Row 42: 'Britain didn't understand #Covid19 for months, while plenty of other countries did understand it and took effective… https://t.co/KV2CAQ6skZ'
# Sentiment: Negative
# Polarity: -0.125
#
# Row 43: 'Volume for those at the back please. 🔊 #COVID19 https://t.co/d0pn2Bv2Hx'
# Sentiment: Neutral
# Polarity: 0.0
#
# Row 44: '#Delhi reports 1,142 #COVID19 positive cases and 29 deaths on Saturday. Death toll rises to 3,806, reports ANI quot… https://t.co/JxsVpWMRQS'
# Sentiment: Positive
# Polarity: 0.22727272727272727
#
# Row 45: '@realDonaldTrump Venezuela's Economy/Budget are tied to Oil like Louisiana's. Funny how the right-wing "example" of… https://t.co/qvHvKlTbbv'
# Sentiment: Positive
# Polarity: 0.25
#
# Row 46: '#TamilNadu | #COVID19 |  25th July
#
# ●  TN - 6,988 (Highest Spike)
#
# ●  Total Cases  - 2,06,737
#
# ●  Chennai - 1,329… https://t.co/X8zgUzC0Gr'
# Sentiment: Neutral
# Polarity: 0.0
#
# Row 47: 'Why has Ruto not eulogisied Mkapa!!
# Asking for Moses Kuria
#
# Raila
# #RutoSwindlingGEMA
# #COVID19'
# Sentiment: Neutral
# Polarity: 0.0
#
# Row 48: 'Coronavirus Testing Fiasco: St Mirren have pledged to undertake an "urgent review" of their Covid-19 testing proced… https://t.co/0MCEUERQ74'
# Sentiment: Neutral
# Polarity: 0.0
#
# Row 49: 'Coronavirus Testing Fiasco: St Mirren have pledged to undertake an "urgent review" of their Covid-19 testing proced… https://t.co/AkxvIaD1Pr'
# Sentiment: Neutral
# Polarity: 0.0
#
# Row 50: '#TamilNadu | #COVID19 |  25th July
# ●  TN - 6,988 (Highest Spike)
# ●  Total Cases  - 2,06,737
# ●  Chennai - 1,329
# ●  T… https://t.co/ZWFKJwZdEo'
# Sentiment: Neutral
# Polarity: 0.0
#
# Row 51: 'Coronavirus Testing Fiasco: St Mirren have pledged to undertake an "urgent review" of their Covid-19 testing proced… https://t.co/Ifse0whbVE'
# Sentiment: Neutral
# Polarity: 0.0
#
# Row 52: 'Coronavirus Testing Fiasco: St Mirren have pledged to undertake an "urgent review" of their Covid-19 testing proced… https://t.co/dx8Yt7CvsM'
# Sentiment: Neutral
# Polarity: 0.0
#
# Row 53: 'Coronavirus Testing Fiasco: St Mirren have pledged to undertake an "urgent review" of their Covid-19 testing proced… https://t.co/h7p44XIzuk'
# Sentiment: Neutral
# Polarity: 0.0
#
# Row 54: 'Testing per 10 lakh population in Jammu and Kashmir has reached 44,744 as against 12,742 in the country; Recovery r… https://t.co/jmxhF67V5V'
# Sentiment: Neutral
# Polarity: 0.0
#
# Row 55: 'Coronavirus Testing Fiasco: St Mirren have pledged to undertake an "urgent review" of their Covid-19 testing proced… https://t.co/bfel6gyXIq'
# Sentiment: Neutral
# Polarity: 0.0
#
# Row 56: 'Coronavirus Testing Fiasco: St Mirren have pledged to undertake an "urgent review" of their Covid-19 testing proced… https://t.co/eu5g2djZYx'
# Sentiment: Neutral
# Polarity: 0.0
#
# Row 57: '.@nytimes reporting that yesterday 1145 people died of #COVID19 in the USA. Over 73K new cases were reported. Serio… https://t.co/sFwP0v7FEB'
# Sentiment: Positive
# Polarity: 0.13636363636363635
#
# Row 58: 'Crazy that the world has come to this but as Americans we will fight to get through this!🇺🇸🇺🇸🇺🇸🇺🇸🇺🇸 #covid19'
# Sentiment: Negative
# Polarity: -0.6
#
# Row 59: '@jimsciutto @JoAnnBaldwin55 People whose relatives have died from #COVID19 should file a class action lawsuit against Sinclair Broadcasting.'
# Sentiment: Positive
# Polarity: 0.1
#
# Row 60: 'US #CoronaVirus: 4,249,584 cases and 148,521 deaths reported in the United States to date.
#
# 1,257 new cases and 31… https://t.co/j4TreMnKW5'
# Sentiment: Positive
# Polarity: 0.13636363636363635
#
# Row 61: '#IndiaFightsCorona :
#
# 📍 Do you agree that a mask is one of the most powerful accessories we have to fight against t… https://t.co/5VauORkmjG'
# Sentiment: Positive
# Polarity: 0.4
#
# Row 62: 'I miss isopropyl alcohol so much!!!! Ethanol in hand sanitizer smells like I poured tequila on my hands 🤢 #COVID19'
# Sentiment: Positive
# Polarity: 0.48828125
#
# Row 63: 'GVMC sanitation staff carrying out the regular sanitation activities to keep the city clean and prevent the spread… https://t.co/bkrQ5x6BCK'
# Sentiment: Positive
# Polarity: 0.18333333333333335
#
# Row 64: '@SonuSood sir mom is in ICU due to COVID just want prayers from you and everyone who is listening you . #COVID19'
# Sentiment: Negative
# Polarity: -0.125
#
# Row 65: 'Due to #COVID19 aka #Coronavirus Ill be sending the first 500 people to like &amp; retweet this $300 -$1500 through Cas… https://t.co/3MkuUsGBDk'
# Sentiment: Negative
# Polarity: -0.125
#
# Row 66: 'This video had me in stitches
# https://t.co/tadF3G6qKJ #obesity #زواج_راكان_الحربي #carryminati #my200vsbutch200… https://t.co/fsZ8NTuVDg'
# Sentiment: Neutral
# Polarity: 0.0
#
# Row 67: 'See this Instagram post by @facts.covid19 https://t.co/glmd51L1OJ
# facts.covid19 Deaths rates not rising in lockste… https://t.co/SeZieeSxAk'
# Sentiment: Neutral
# Polarity: 0.0
#
# Row 68: 'Local government sales tax revenue dropped 27 percent year-to-year in the second quarter, thanks to #COVID19 shutdo… https://t.co/oDky9LzrV5'
# Sentiment: Positive
# Polarity: 0.06666666666666667
#
# Row 69: 'Look at Lil’ Donny Micro Dick go!! What an astounding achievement of brilliance + cognitive capabilities. Somebody… https://t.co/82aEo6gL3q'
# Sentiment: Positive
# Polarity: 0.6
#
# Row 70: 'While you at it, please follow me
#
# https://t.co/KheirQEh6Z
#
# #Fergusons #DurbanJuly #alreadyvideo #COVID19 #WiseUp https://t.co/h1TYdOgjwv'
# Sentiment: Neutral
# Polarity: 0.0
#
# Row 71: 'Concealed Nation 1 Million Giveaway https://t.co/HaMym0cBe3
# I put my family's safety before all others, criminals… https://t.co/7QQxVLWqZd'
# Sentiment: Neutral
# Polarity: 0.0
#
# Row 72: 'Check out Angel's beautiful mask and hair bow designs at https://t.co/BpmP8tRs7M #etsy #epiconetsy #masksforsale… https://t.co/fgl69zjMyq'
# Sentiment: Positive
# Polarity: 0.85
#
# Row 73: 'Thread by @DrZoeHyde (based on international research and evidence) 1. Updated thread on children and #COVID19, sum… https://t.co/A1xWVotp75'
# Sentiment: Neutral
# Polarity: 0.0
#
# Row 74: '1 municipality reports one new fatality due to #COVID19, compared to yesterday.
#
# 1 new fatality is located and 0 fa… https://t.co/6iJ5lV7ZqR'
# Sentiment: Positive
# Polarity: 0.04924242424242423
#
# Row 75: 'When your home walls need an upgradation, always opt for the experts. Hire #MumbaiPainters and let your walls find… https://t.co/Kb5Yv2ZS9Z'
# Sentiment: Neutral
# Polarity: 0.0
#
# Row 76: 'Covid to shrink power sector growth, take discoms back to pre-UDAY era
#
# https://t.co/DP5zpNLuUV
#
# #Industry… https://t.co/3ZiFoPdWU8'
# Sentiment: Neutral
# Polarity: 0.0
#
# Row 77: '#SaturdayVibes: The current situation calls for more awareness and less stress. To facilitate that, families at our… https://t.co/1Qwd523BZp'
# Sentiment: Positive
# Polarity: 0.11111111111111112
#
# Row 78: 'What economic measures are governments taking to respond to #COVID19? Key actions taken by 193 countries are listed… https://t.co/5FXaZWFaLW'
# Sentiment: Positive
# Polarity: 0.1
#
# Row 79: '“#Covid19 is everyone’s fight. I have covered major disasters, but nothing like this before."
#
# @fabeha_monir, a vi… https://t.co/q3f9kP8rsq'
# Sentiment: Positive
# Polarity: 0.0625
#
# Row 80: '@Haggis_UK “I think the government has hugely overestimated the danger of the disease”
# I wonder if he’d be brave en… https://t.co/gWJc6nUKqo'
# Sentiment: Positive
# Polarity: 0.6000000000000001
#
# Row 81: 'By the time you see a spike in #Covid19 cases, it isvery hard to reverse it without drastic lockdown. By the time y… https://t.co/A3S4AK3JH4'
# Sentiment: Negative
# Polarity: -0.2916666666666667
#
# Row 82: '@realDonaldTrump @WhiteHouse See what your #political games with #Covid19 have achieved? This is not only shameful… https://t.co/JXvuzUqwfC'
# Sentiment: Neutral
# Polarity: 0.0
#
# Row 83: 'Hi long time no see...... In preparation for us reopening we have been doing our homework and some...... #clean… https://t.co/GjEe5w9uY2'
# Sentiment: Negative
# Polarity: -0.05
#
# Row 84: '@theJagmeetSingh @MatthewGreenNDP you took money at the beginning of the pandemic from woman front line workers who… https://t.co/NXYIA38Rj6'
# Sentiment: Neutral
# Polarity: 0.0
#
# Row 85: 'How Ireland built its COVID-19 contract tracing app, which is so successful that U, S. states want to use it… https://t.co/f0DavA6psh'
# Sentiment: Positive
# Polarity: 0.75
#
# Row 86: 'Rakesh Sharma best business Coach in India
# Website: https://t.co/oG44LxC2Gg
# #salescoach
# #BusinessCoach
# #salesforce… https://t.co/GkipPLJMX9'
# Sentiment: Positive
# Polarity: 1.0
#
# Row 87: 'Think the link between 5G and #COVID19 is the stuff of loony conspiracy-theories?
# Think again: this screen-shot is… https://t.co/UFXNtHGa7L'
# Sentiment: Neutral
# Polarity: 0.0
#
# Row 88: '#NSTworld There will not be a #NationalDayRally (#NDR) this year, due to safe distancing requirements as a result o… https://t.co/XJMZjyPCrn'
# Sentiment: Positive
# Polarity: 0.1875
#
# Row 89: 'The cost of preventing further pandemics over the next decade by protecting wildlife and forests would equate to ju… https://t.co/8yqpH3GrLf'
# Sentiment: Neutral
# Polarity: 0.0
#
# Row 90: 'Learn new things during this period
# 2d and 3d animations training ongoing...
# Click the link below to join the What… https://t.co/lLovm5cWPi'
# Sentiment: Positive
# Polarity: 0.13636363636363635
#
# Row 91: '2,000 women lawyers write to #AmitShah seeking 5 Lakh Loan per financially drained lawyer.
# #COVID19 #Coronavirus
# https://t.co/JEjVTeCjEn'
# Sentiment: Neutral
# Polarity: 0.0
#
# Row 92: 'I literally am using my own head to make decisions on safety from #COVID19 as government are creating the most conf… https://t.co/Kji4e3yBty'
# Sentiment: Positive
# Polarity: 0.55
#
# Row 93: 'OK I'm angry now. I cannot believe the stupidity there is out there about #COVID19. This virus kills. How many must… https://t.co/kNBiYfPTXB'
# Sentiment: Negative
# Polarity: -0.024999999999999994
#
# Row 94: '#DurbanJuly  It's that weekend Y,all... It's a pity that this year we are facing #COVID19 and we can't go in person… https://t.co/k451xx2Ynv'
# Sentiment: Negative
# Polarity: -0.1
#
# Row 95: 'Let's give it a try #alreadyvideo #COVID19 #HurricaneHanna https://t.co/2HChuAfNHy'
# Sentiment: Neutral
# Polarity: 0.0
#
# Row 96: 'Shout out to Earth. Hands down the worst reaction to a “emergency” I’ve ever seen. The Lottery never shut down and… https://t.co/wLGZ8wHymT'
# Sentiment: Negative
# Polarity: -0.4370370370370371
#
# Row 97: '#TamilNadu | #COVID19 |  25th July
#
# ●  TN - 6,988 (Highest Spike)
#
# ●  Total Cases  - 2,06,737
#
# ●  Chennai - 1,329… https://t.co/BFYb3AHGBi'
# Sentiment: Neutral
# Polarity: 0.0
#
# Row 98: '@WLOS_13 @wcti12 @thecw22 @myrdc @ABC45TV Please tell us you not going to run that Qanon conspiracy
# theory (banned… https://t.co/bYOIITE5kh'
# Sentiment: Neutral
# Polarity: 0.0
#
# Row 99: 'You can all #PlayYourPart in the fight against #Covid19.  We’re all #InThisTogether. Cavan Ladies Footballer Aishli… https://t.co/JtU6MDq2tl'
# Sentiment: Neutral
# Polarity: 0.0
#
# Row 100: 'The Egyptians ain't got shit on this. #COVID19 https://t.co/kl5lzOJaxO'
# Sentiment: Negative
# Polarity: -0.2
#
# Row 101: 'Voices from the Belt and Road: COVID-19 rap song alerts to needed precautions when returning to work
# #beltandroad… https://t.co/O39NmfUDmc'
# Sentiment: Neutral
# Polarity: 0.0
#
# Row 102: 'PR :  @VishalKOfficial and his father Mr.G.K.Reddy tested positive for #Covid19 15/20 days back..
#
# While #Vishal 's… https://t.co/CSXEqIWtig'
# Sentiment: Positive
# Polarity: 0.11363636363636363
#
# Row 103: 'Not only is the area about to be hit by #hanna a #COVID19 hotspot, but Hurricane Harvey work is ongoing. Still.'
# Sentiment: Neutral
# Polarity: 0.0
#
# Row 104: '1.28% of the U.S. population is infected with Covid-19
# #COVID19
# #TrumpVirus
# #MaskItOrCasket'
# Sentiment: Neutral
# Polarity: 0.0
#
# Row 105: 'My latest on #FoxNews - #COVID19 keeps Wish Children waiting as #WaltDisneyWorld re-opens. @GKTWVillage unable to b… https://t.co/jXCXwifFTb'
# Sentiment: Neutral
# Polarity: 0.0
#
# Row 106: '@Prof_Wombat @vickihickory @ROhsolovely @realDonaldTrump Imagine thinking your toddler-in-chief didn't ignore it ja… https://t.co/MtM8ESVchV'
# Sentiment: Neutral
# Polarity: 0.0
#
# Row 107: '.@headout with a dashboard to boost post-#COVID19 #travel https://t.co/0gnRgqvLlh'
# Sentiment: Neutral
# Polarity: 0.0
#
# Row 108: '#coronavirus #COVID19 disproportionately affecting communities of color, especially #Hispanic #Latinx ones in my ho… https://t.co/01gV4rcK1u'
# Sentiment: Neutral
# Polarity: 0.0
#
# Row 109: 'As debates ensue about reopening schools 🏫 amid #COVID19, @WomenDeliver Young Leader @olorunisola8 of #Nigeria says… https://t.co/EGkaAKXGym'
# Sentiment: Positive
# Polarity: 0.1
#
# Row 110: 'Companies must protect their workforce’s physical and mental health during the crisis. The use of smart technology,… https://t.co/uExGQbwx1I'
# Sentiment: Positive
# Polarity: 0.03809523809523809
#
# Row 111: 'Today's cases:  92
# Total cases: 4102
# Today's sample: 602
# Today's cured: 45
# Total cured: 3233
# Today's death: 2
# Total… https://t.co/tmrdKOWoma'
# Sentiment: Neutral
# Polarity: 0.0
#
# Row 112: '#DrKawana, Minister of Fisheries and Marine Resources, what’s the hold up now? Please release announce the names of… https://t.co/WurEtJyKGX'
# Sentiment: Neutral
# Polarity: 0.0
#
# Row 113: 'Highest ever number of new cases yesterday #coronavirus #covid19 #STAYatHOME https://t.co/oovQrvMviY'
# Sentiment: Positive
# Polarity: 0.13636363636363635
#
# Row 114: '@eldiablo0786 @outercircles @RedMajid @A34SafetyAction @BrumLeader @elaina22475794 @CllrMajid @AKAsusangreen… https://t.co/AkiidjpCpe'
# Sentiment: Neutral
# Polarity: 0.0
#
# Row 115: '@toadmeister Yes, evidence has increased. Plus early WHO guidance was due to the global PPE shortage - priority to… https://t.co/Emdvdhx9Nw'
# Sentiment: Negative
# Polarity: -0.008333333333333331
#
# Row 116: '@bubbaprog 350 school employees exposed to #COVID19 in Manatee County schools over the summer https://t.co/GxiYb61ay0'
# Sentiment: Neutral
# Polarity: 0.0
#
# Row 117: '@BenJamesPhotos Italy #BenPC  #LOCKDOWNPHOTOCHALLENGE #COVID19 https://t.co/27jyDBhbMc'
# Sentiment: Neutral
# Polarity: 0.0
#
# Row 118: 'Cum Check It Out. Ill DM You Nudes!
# https://t.co/93MX6QIvAS
# #onlyfansbabe #ihaveajoke #onlyfansgirl #alreadyvideo… https://t.co/VHgsyRMeiM'
# Sentiment: Negative
# Polarity: -0.625
#
# Row 119: 'If CM of Madhya Pradesh is tested positive for COVID, then Scindia should also be tested for #COVID19.'
# Sentiment: Positive
# Polarity: 0.22727272727272727
#
# Row 120: 'Four mayors reflect on their evolving response to the coronavirus pandemic https://t.co/TMqFfkPjcC  👈 click the lin… https://t.co/ZmqzTU7Nsv'
# Sentiment: Neutral
# Polarity: 0.0
#
# Row 121: 'Bihar witnesses biggest single-day spike of 2,803 new #Covid19 cases
#
# https://t.co/zTPksALE7T https://t.co/979SPKzt3w'
# Sentiment: Positive
# Polarity: 0.13636363636363635
#
# Row 122: 'Lunch in #Amsterdam away from the mass tourists that have invaded so quickly during the #COVID19 pandemic ! #travel https://t.co/DBCPWA0Ao9'
# Sentiment: Positive
# Polarity: 0.41666666666666663
#
# Row 123: 'We've captured a snapshot of the amazing VCSE response to the #COVID19 pandemic in Salford.
#
# We want to say thank… https://t.co/kPum9Ajq72'
# Sentiment: Positive
# Polarity: 0.6000000000000001
#
# Row 124: 'About 22,000 nonprofits will eventually close their doors for good as a result of the current economic crisis, acco… https://t.co/2PSnJgFVfd'
# Sentiment: Positive
# Polarity: 0.3
#
# Row 125: 'Punjab Govt Warns People Not to Click on Any URL Circulated via SMS/WhatsApp Claiming COVID-19 Relief Package of Rs… https://t.co/tOVrae0N2V'
# Sentiment: Neutral
# Polarity: 0.0
#
# Row 126: 'The worst type of spread. #COVID19 #COVIDー19 #COVIDIOTS https://t.co/zyhtCU0A4B'
# Sentiment: Negative
# Polarity: -1.0
#
# Row 127: 'Wells Fargo Tightens Purse Strings to Ride Out Coronavirus Pandemic
#
# READ MORE: https://t.co/c86mzwRrnK
#
# #cdc… https://t.co/TJIxxLyVhQ'
# Sentiment: Positive
# Polarity: 0.5
#
# Row 128: 'This is a really informative and interesting 🧵. Lots to think about, especially if you have school age kids.… https://t.co/hBee6ZGnYA'
# Sentiment: Positive
# Polarity: 0.2333333333333333
#
# Row 129: '@travellerboxers Agreed !!  💯%
#  But why I mean, what exactly was his problem with travellers ❤️
#  He needs educatin… https://t.co/TdlxiJKpCV'
# Sentiment: Negative
# Polarity: -0.03125
#
# Row 130: 'Veteran Affairs reports 252 new cases and 13 new deaths bringing total confirmed cases there to 35,563 and 1,980 to… https://t.co/92FnCL6EVR'
# Sentiment: Positive
# Polarity: 0.13454545454545455
#
# Row 131: 'Irish home / commercial building model is the perfect breathing groung for the #COVID19  virus. Each trade is treat… https://t.co/YNyXtWrnCC'
# Sentiment: Positive
# Polarity: 0.3333333333333333
#
# Row 132: '"Think-piece on Gender and Climate Change in the context of #COVID19"
#
# https://t.co/BJE2s3WtG7
#
# @parimitaenergy… https://t.co/cVGpy53RNK'
# Sentiment: Neutral
# Polarity: 0.0
#
# Row 133: '#Leicestershire residents – if you develop any #Covid19 symptoms, even mild ones, book a test immediately at… https://t.co/Nmz8sJORJp'
# Sentiment: Positive
# Polarity: 0.3333333333333333
#
# Row 134: 'I’m emotionally exhausted find my way coming soon ‼️#my200vsbutch200 #royalehightrades #alreadyvideo #MTVHotttest… https://t.co/LsqaRfGoAn'
# Sentiment: Negative
# Polarity: -0.4
#
# Row 135: 'Actor @VishalKOfficial and his father Mr. GK Reddy tested positive for #Covid19 a couple of weeks ago.
#
# #Vishal's f… https://t.co/6kk3mBMcIQ'
# Sentiment: Positive
# Polarity: 0.22727272727272727
#
# Row 136: 'Just imagine...going back to sitting on an average of nearly 6.2 DAYS / year in the car in standstill traffic in Lo… https://t.co/kReiLNFqav'
# Sentiment: Negative
# Polarity: -0.016666666666666663
#
# Row 137: 'Global fatalities chart for the last 24 hours..#COVID19
#
# 1. Bolsonaro
# 2. Trump
# 3. Modi https://t.co/D7BHp4xEE3'
# Sentiment: Neutral
# Polarity: 0.0
#
# Row 138: 'You don't drown by falling into a river, but by staying submerged in it.
#
# #facts #SaturdayMotivation #truth… https://t.co/Cl9uVqkTUK'
# Sentiment: Neutral
# Polarity: 0.0
#
# Row 139: '#COVID19:  #UttarPradesh CM @myogiadityanath directs officials to enhance #COVID-19 testing capacity to one lakh te… https://t.co/k67oJRG3Q8'
# Sentiment: Neutral
# Polarity: 0.0
#
# Row 140: 'Sounds like Plandemic is about to get a second life. Here’s a thread from it’s first run, that debunks its major cl… https://t.co/uGOPrGxbCp'
# Sentiment: Positive
# Polarity: 0.10416666666666667
#
# Row 141: '@princesscaro85 @NVGOP @marquezjesso @andylukechoi @FlocchiniAmanda @LaCubanaMisfit You should know better. Trump,… https://t.co/mEmjKjB4eN'
# Sentiment: Positive
# Polarity: 0.5
#
# Row 142: 'For me, someone who has been affected by social anxiety, wearing a face mask is amazing. I feel slightly hidden fro… https://t.co/t5zBRcraUp'
# Sentiment: Positive
# Polarity: 0.15555555555555559
#
# Row 143: '@badbitchinaz I’d pay the Republicans to leave America #VoteBlue2020 #VoteForBiden #VoteBlueToEndThisNightmare… https://t.co/bGRMueT7WS'
# Sentiment: Neutral
# Polarity: 0.0
#
# Row 144: 'Vietnam’s high level of preparedness to prevent Covid-19 spread: Deputy PM #Vietnam #covid19 #coronavirus #ncov… https://t.co/H2hJRzkEZl'
# Sentiment: Positive
# Polarity: 0.16
#
# Row 145: '@KGeorgieva @Lenin You're totally wrong. Ecuador is the Latin American country with the most causable mortality wit… https://t.co/w1xlNgLeSJ'
# Sentiment: Neutral
# Polarity: 0.0
#
# Row 146: '@CBCTheHouse @PattyHajdu @CochraneCBC #Covid19 Fatigue, people in front lines we cannot replace,  that is #Fatigue!… https://t.co/8pk0Vik8gX'
# Sentiment: Neutral
# Polarity: 0.0
#
# Row 147: 'We provided a North Devon tourist attraction with a digital #twowayradio solution even before #COVID19 struck. As w… https://t.co/kLwJHahlkq'
# Sentiment: Neutral
# Polarity: 0.0
#
# Row 148: 'Mask Print #1 (Londoners Wear Masks) https://t.co/N1zwBuf1No #MaskUp #mask #Masks #MaskMoaners #COVID19 #COVIDー19… https://t.co/W7uBNQomP2'
# Sentiment: Neutral
# Polarity: 0.0
#
# Row 149: '#RepublicansForBidenNow #COVID19
# Republican Group Uses Trump's Own Words Against Him In Searing Swing-State Ad… https://t.co/9fhivsvvHf'
# Sentiment: Positive
# Polarity: 0.6
#
# Row 150: '@SkyNews Of course it's #COVID19 and absolutely nothing to do with this diabolical government who had almost triple… https://t.co/7JnGp3JLZW'
# Sentiment: Positive
# Polarity: 0.2
#
# Row 151: 'I had the opportunity to discuss the legacy of mistrust that Black communities have towards the medical community a… https://t.co/6EBJDIzuZT'
# Sentiment: Negative
# Polarity: -0.08333333333333333
#
# Row 152: 'How about everyone can spread #COVID19. Another study not accurate! https://t.co/8h5OC3AzYq'
# Sentiment: Negative
# Polarity: -0.25000000000000006
#
# Row 153: 'Learning is fun, interesting and surprisingly quite easy. Let’s join WLF Nigeria Ambassadors to promote learning a… https://t.co/rj1wtaf3uV'
# Sentiment: Positive
# Polarity: 0.48333333333333334
#
# Row 154: 'Today's the day for #TheBigSpend to buy local &amp; support our #COVID19 rebuilding process. Shop at a local small busi… https://t.co/4xXcPttzqg'
# Sentiment: Negative
# Polarity: -0.08333333333333333
#
# Row 155: '@realDonaldTrump You mean you actually did your JOB after almost 4 years of dodging it?
#
# I don’t get thanked for do… https://t.co/gZcEljJQp5'
# Sentiment: Negative
# Polarity: -0.15625
#
# Row 156: '#TravelTuesday #COVID19 *Excellent data charts which map how CV is progressing through our societies. They are also… https://t.co/TswUuwfSWY'
# Sentiment: Positive
# Polarity: 1.0
#
# Row 157: '@HouseofBobber @SmithWinstona @BlackManOfKAG @cangal21 What a coincidence, influenza cases are unusually down.… https://t.co/UCeqTLOtIF'
# Sentiment: Positive
# Polarity: 0.2
#
# Row 158: '7813 new positive #COVID19 cases reported in #AndhraPradesh from last 24hours
#
# #APFightsCorona #StayHome https://t.co/MkpUtMvtyZ'
# Sentiment: Positive
# Polarity: 0.12121212121212122
#
# Row 159: '(1) Two quick estimates of the Arizona post apex recovery rate:
#
# 7/03:  3,849 7d avg Peak #COVID19 Confirmed Cases… https://t.co/Tsi7BpsqJQ'
# Sentiment: Positive
# Polarity: 0.3666666666666667
#
# Row 160: '#AR State Sen. Jason Rapert Preached at a Mask-Free Church; Now He Has COVID https://t.co/J9rcqicIHc
# I'm sorry--is… https://t.co/A6dvDYcP7i'
# Sentiment: Neutral
# Polarity: 0.0
#
# Row 161: 'Trump hates looking like a loser — right now he looks like one of the biggest losers in U.S. history: op-ed… https://t.co/5W9ybguQuX'
# Sentiment: Positive
# Polarity: 0.042857142857142844
#
# Row 162: 'You want to cheat in WAEC which are you carrying #BBNajia #COVID19 #TachaDanceChallange #SayNoToNipostFee… https://t.co/4sEtgTAPNY'
# Sentiment: Neutral
# Polarity: 0.0
#
# Row 163: '#Kerala Private hospitals #covid treatment rates in ₹
# General Ward 2300
# HDU 3300
# ICU 6500
# ICU ventilator 11,500
# In… https://t.co/NWgix2xAUj'
# Sentiment: Positive
# Polarity: 0.02500000000000001
#
# Row 164: 'Due to the epidemic I'm giving $80 - $1000 to any person out there looking, it might not be able to go round but i… https://t.co/BfX03CbW6F'
# Sentiment: Positive
# Polarity: 0.05833333333333333
#
# Row 165: '@JoeBiden What fight is the creepy and delusional basement dweller referring to? The only battle is keeping… https://t.co/gD8rzRpSc5'
# Sentiment: Negative
# Polarity: -0.25
#
# Row 166: '395 new cases and 3 new deaths in Uzbekistan
#
# [13:22 GMT] #coronavirus #CoronaVirusUpdate #COVID19 #CoronavirusPandemic'
# Sentiment: Positive
# Polarity: 0.13636363636363635
#
# Row 167: '#BIGNEWS: #Rajasthan Governor Kalraj Mishra appeals to all #COVID19 recovered patients to donate their plasma, says… https://t.co/oNsDHDdaYG'
# Sentiment: Neutral
# Polarity: 0.0
#
# Row 168: '“Until the day we have a medical vaccine, food is the best vaccine against chaos.”  - @WFPChief David Beasley.
#
# Am… https://t.co/pEYhGxDRPN'
# Sentiment: Positive
# Polarity: 0.5
#
# Row 169: 'In Nigeria hapless and unfortunate citizens are taxed ever increasing tariffs for these things. Even without lettin… https://t.co/860upMqDYV'
# Sentiment: Negative
# Polarity: -0.55
#
# Row 170: 'Your friendly weekend reminder that COVID didn’t go away because you got bored.
#
# #wearamask #covid #covid19… https://t.co/5Xjoivu9Ze'
# Sentiment: Negative
# Polarity: -0.0625
#
# Row 171: 'Local TV stations owned by Sinclair Broadcast Group are set to air discredited Plandemic researcher's conspiracy th… https://t.co/RBoQTSdsns'
# Sentiment: Neutral
# Polarity: 0.0
#
# Row 172: 'Photos: #UAE hospital launches support group for #Covid19 patients https://t.co/wLnFggHSQL'
# Sentiment: Neutral
# Polarity: 0.0
#
# Row 173: '@Intuitive1966 Yes but
# “we’re learning more about #COVID19 every day” &amp;
# “we’re listening to the science”.… https://t.co/aJW17HoIu8'
# Sentiment: Positive
# Polarity: 0.5
#
# Row 174: 'Alhamdulillah ❤️
# Coronavirus: No deaths reported for 48 hours in Qatar. 🙏🙏🙏
#
# #Qatar #COVID19 #Coronavirus… https://t.co/29PAfpdt5x'
# Sentiment: Neutral
# Polarity: 0.0
#
# Row 175: 'PRANIK'S Giloy Capsules gives you far-reaching benefits to fight against the infections and boost your immunity.… https://t.co/JlZXHZT1A1'
# Sentiment: Neutral
# Polarity: 0.0
#
# Row 176: '#COVID19: 5,690 RTPCR/CBNAAT/TrueNat tests and 14,819 Rapid antigen tests conducted today. A total of 9,29,244 test… https://t.co/LtdrWlVZiX'
# Sentiment: Neutral
# Polarity: 0.0
#
# Row 177: '@RepMattGaetz @realDonaldTrump @GaetzTakes How much will dead and  #COVID19 sufferers spend?'
# Sentiment: Neutral
# Polarity: 0.0
#
# Row 178: '#Virtual #CHRO #PanelDiscussion on Re-imagining #workplaces amid #COVID19 on July 29
# Register @… https://t.co/OQhX0QZD4I'
# Sentiment: Neutral
# Polarity: 0.0
#
# Row 179: '@GovernorGreg’s actions killed.  Are still killing.
#
# What’s that word we use for people who willfully and intention… https://t.co/6NUDsOh6zS'
# Sentiment: Negative
# Polarity: -0.2
#
# Row 180: 'Are people working in shops supposed to wear face covering? #COVID19 #England'
# Sentiment: Neutral
# Polarity: 0.0
#
# Row 181: 'Delta flight departing from Detroit has to turn around as 2 guests refuse to wear masks
# #airlines
# #coronavirus… https://t.co/vFyQ1AFrB7'
# Sentiment: Neutral
# Polarity: 0.0
#
# Row 182: '@fkeyamo Please can someone educate me on the application process since physical presence isn't possible due to… https://t.co/bD3Iek1PkE'
# Sentiment: Negative
# Polarity: -0.041666666666666664
#
# Row 183: 'Puerto Rico reports 573 new cases and 10 new deaths bringing total confirmed cases there to 14,540 and 201 total de… https://t.co/iNO9S2jXVY'
# Sentiment: Positive
# Polarity: 0.13454545454545455
#
# Row 184: '1,142 #COVID19 positive cases, 2,137 patients recovered/discharged/migrated and 29 deaths in Delhi today. There are… https://t.co/qF6QYCjcmd'
# Sentiment: Positive
# Polarity: 0.22727272727272727
#
# Row 185: 'Dying WITH #COVID19 is not the same as
#
# Dying from #COVID19- huge difference.
#
# The #FakeNews and #Democrats are usi… https://t.co/6JY9Z05zEf'
# Sentiment: Positive
# Polarity: 0.20000000000000004
#
# Row 186: 'If you thought that you would have a shorter line by arrive 45 min early at the brewer testing center.... you would… https://t.co/DQxat0X8xO'
# Sentiment: Neutral
# Polarity: 0.0
#
# Row 187: '#Airlines that design #COVID19 recovery plans with human-centered mindset will likely be in the best position to th… https://t.co/aAfvuqvW0v'
# Sentiment: Positive
# Polarity: 0.5
#
# Row 188: 'Deeply saddened by the untimely demise of Constable Krishna Kanta Burman due to #COVID19. He was posted in Hastings… https://t.co/uo48jr8l10'
# Sentiment: Negative
# Polarity: -0.0625
#
# Row 189: '#Maharashtra Government Cuts Syllabus by 25% For Students in Class 1-12 in View of #COVID19 Pandemic, Says School E… https://t.co/H58P59UuMV'
# Sentiment: Neutral
# Polarity: 0.0
#
# Row 190: '#Jaipur | Rajasthan Government today started a #PlasmaBank at Sawai Man Singh Hospital in Jaipur for treatment of… https://t.co/J1geY43a16'
# Sentiment: Neutral
# Polarity: 0.0
#
# Row 191: '@USCIS unlike most of the federal government, largely depends on funding from fees it collects on citizenship, gree… https://t.co/7TCmWf6PU5'
# Sentiment: Positive
# Polarity: 0.35714285714285715
#
# Row 192: 'Big Q: Parents: if you have flexibility to work from home or send your child to school, what would data/information… https://t.co/tw7Dz1V0OG'
# Sentiment: Neutral
# Polarity: 0.0
#
# Row 193: 'How is the US such a colossal #COVID19 failure? https://t.co/jKcTgTF67V'
# Sentiment: Negative
# Polarity: -0.005555555555555573
#
# Row 194: '#Win a copy of the @positiv_planner with @motherhoodreal to support your #mentalhealth after #Covid19:… https://t.co/6pYVeIIBJm'
# Sentiment: Positive
# Polarity: 0.8
#
# Row 195: 'Rutland's own, supporting #COVID19 testing https://t.co/sVtRf11T3s'
# Sentiment: Positive
# Polarity: 0.425
#
# Row 196: '@urstrulyMahesh @SCSC_Cyberabad @cyberabadpolice It's time all our beloved survivors of #COVID19 should now be a… https://t.co/QFrBbHlsd7'
# Sentiment: Positive
# Polarity: 0.7
#
# Row 197: '100% feeling good and 0% some symptoms🙃 Long May it last 🤞🏻 #COVID19 🦠🤛🏻 https://t.co/37Dc8BweJO'
# Sentiment: Positive
# Polarity: 0.21666666666666665
#
# Row 198: 'You want to understand Improving Quality? It represents the soap and water to wash your hands with during #COVID19.… https://t.co/EnzxPEExIJ'
# Sentiment: Neutral
# Polarity: 0.0
#
# Row 199: '@TheDailyEdge @seanhannity @FoxNews So he can spread lies, hate, sexual violence, and murder. #COVID19 #FoxNews'
# Sentiment: Negative
# Polarity: -0.15000000000000002
#
# Row 200: 'Just home from town &amp; there were so many people wearing masks incorrectly. I feel a bit frustrated by it but I’m ch… https://t.co/wTwZ1seQhV'
# Sentiment: Negative
# Polarity: -0.09999999999999998
#
# Row 201: '##COVID19 and New York retail https://t.co/aUv60GNyfE'
# Sentiment: Positive
# Polarity: 0.13636363636363635
#
# Row 202: '#COVID19: Delhi reported 1,142 new cases and 29 deaths today, taking the total number of cases to 1,29,531 and death tally to 3,806.'
# Sentiment: Positive
# Polarity: 0.06818181818181818
#
# Row 203: 'How can tech leaders help position their organization’s #techstrategy in a way that aligns with shifting investment… https://t.co/AIDJS3QvvA'
# Sentiment: Neutral
# Polarity: 0.0
#
# Row 204: '#Danang #COVID19 patient's health gets worse quickly, prompting doctors to use #ECMO &amp; filter blood… https://t.co/0c09GtUX61'
# Sentiment: Negative
# Polarity: -0.033333333333333354
#
# Row 205: '@UrsulaIreneRay1 @VijayShadean #SouthAfrica #tourism @GoToSouthAfrica #CarteBlanche #COVID19 #Cricket #Rugby not sure of the breed'
# Sentiment: Negative
# Polarity: -0.25
#
# Row 206: 'How has having #ColleaguesForLife helped #DeloitteAlumni Karen Seminara-Patton co-found an organization to help med… https://t.co/xcbg2VesYY'
# Sentiment: Neutral
# Polarity: 0.0
#
# Row 207: 'Successful #openingday with a #grandslam #walkoff by matt_olson21 !Was anyone else thinking: SIX FEET, with this ce… https://t.co/x8WJ0FnIFq'
# Sentiment: Positive
# Polarity: 0.9375
#
# Row 208: '#Brazil’s #Bilsonaro who tested positive for #COVID19 says his latest test result was negative.'
# Sentiment: Positive
# Polarity: 0.14242424242424243
#
# Row 209: 'From more than 1,000 deaths in the US, fourth day in a row to questions about the global supply chain's ability to… https://t.co/wP58MfbT8E'
# Sentiment: Positive
# Polarity: 0.16666666666666666
#
# Row 210: 'If you have been affected by the brief #COVID19 lock down, take some time to think of the animals we have permanent… https://t.co/6mEum6Ruau'
# Sentiment: Negative
# Polarity: -0.07777777777777779
#
# Row 211: '#COVID19: 1,142 positive cases, 2,137 patients recovered/discharged/migrated and 29 deaths in #Delhi today. There a… https://t.co/i8m34hJodD'
# Sentiment: Positive
# Polarity: 0.22727272727272727
#
# Row 212: 'Check out my latest article: Three Supply Chain Risks That Could Thwart A Successful COVID-19 Vaccine… https://t.co/3Tdkknwns7'
# Sentiment: Positive
# Polarity: 0.625
#
# Row 213: 'STOP FOGGY GLASSES WITH THIS HACK!!!!!! #COVID19 #facecoverings #maskproblems #facemask #hack #maskhack #MaskMoaners https://t.co/IjuRQVuBHL'
# Sentiment: Neutral
# Polarity: 0.0
#
# Row 214: 'Symptom Duration and Risk Factors for Delayed Return to Usual Health Among Outpatients with #COVID19 in a Multistat… https://t.co/wNUL5Bd5Ok'
# Sentiment: Negative
# Polarity: -0.25
#
# Row 215: '#COVID19 is the religion of 21st Century Jews fighting 21st Century Christian Evangelicals'
# Sentiment: Neutral
# Polarity: 0.0
#
# Row 216: '@kenolin1 That's an admission from @realDonaldTrump, probably the only truth we'll ever hear from him, that he regr… https://t.co/QgrbHcUvy8'
# Sentiment: Neutral
# Polarity: 0.0
#
# Row 217: 'There must be bad #times in order to appreciate the #good ones. ~Jeffrey Duarte https://t.co/rRoQRhtM5Z
# #depression… https://t.co/AetE9xyDbc'
# Sentiment: Positive
# Polarity: 5.551115123125783e-17
#
# Row 218: 'PR :  @VishalKOfficial and his father Mr.G.K.Reddy tested positive for #Covid19 15/20 days back..
#
# While #Vishal 's… https://t.co/wV5foDZswX'
# Sentiment: Positive
# Polarity: 0.11363636363636363
#
# Row 219: '@BenJamesPhotos Pink #BENPC #LOCKDOWNPHOTOCHALLENGE #COVID19 #SaturdayMorning #flowers https://t.co/DLGgosBPjQ'
# Sentiment: Negative
# Polarity: -0.1
#
# Row 220: 'National and state impact of #COVID19 on our elder population. This is a societal loss of wisdom, history, and of s… https://t.co/4gaIfWiDcB'
# Sentiment: Neutral
# Polarity: 0.0
#
# Row 221: '#COVID19 in #AndhraPradesh:
#
# -7,813 new cases
# -52 more deaths
# -53,681 more samples tested
# -3,208 more discharged
# -E… https://t.co/lKlZORk7r7'
# Sentiment: Positive
# Polarity: 0.40909090909090906
#
# Row 222: 'ALERT: Eye Opener: Rep. John Lewis remembered - Global Pandemic News | #Coronavirus #COVID19 #Protests -… https://t.co/D8C1Ps4ebx'
# Sentiment: Neutral
# Polarity: 0.0
#
# Row 223: 'My uncle just tested positive for #COVID19 , we already lost 3 family members.
#
# PLEASE wear a mask,social distance. https://t.co/YoXI0LbeLI'
# Sentiment: Positive
# Polarity: 0.22727272727272727
#
# Row 224: 'Venrap Radio Now Playing Venrap Radio by Stay safe during this #COVID19 we love you Download our app or listen on… https://t.co/eQQGBJ8M5E'
# Sentiment: Positive
# Polarity: 0.5
#
# Row 225: '“The anxiety surrounding COVID-19 has caused Bipolar and Chron’s Disease to flare up quite badly”
#
# Read more of you… https://t.co/oMFMm4ALPR'
# Sentiment: Negative
# Polarity: -0.09999999999999992
#
# Row 226: 'We Shall Over Come! With victory in our minds in our #FightAgainstCorona, our retail outlets across India are adher… https://t.co/qwNPUCXbxj'
# Sentiment: Neutral
# Polarity: 0.0
#
# Row 227: 'Absolutely NO... If they had, we wouldn't be standing at 3rd position worldwide with more than 12 lakh #COVID19 cas… https://t.co/qxWoJLGCaZ'
# Sentiment: Positive
# Polarity: 0.13333333333333333
#
# Row 228: '#CORONAVIRUS update 7/25/2020:
# *Nearly 40 countries report record single-day increases in infections.
# *US records o… https://t.co/PbHPWgfd6U'
# Sentiment: Positive
# Polarity: 0.1
#
# Row 229: 'In the US, even those with insurance face possible economic burdens from the pandemic.
#
# Tens of millions of America… https://t.co/Wje81ryIkV'
# Sentiment: Positive
# Polarity: 0.1
#
# Row 230: 'Undercover inspectors are deployed by the @AbuDhabiDED to make sure that all anti- #Covid19 measures are being foll… https://t.co/LNdyGBFXIt'
# Sentiment: Positive
# Polarity: 0.5
#
# Row 231: 'Hospital cleaners, porters &amp; catering staff are unsung #COVID19 heroes. Tell @issworld to pay them a fair wage… https://t.co/tSrg8MgqLx'
# Sentiment: Positive
# Polarity: 0.7
#
# Row 232: '#Manufacturing production activity begins to echo 2019 trends, indicating further industry normalization. But will… https://t.co/ZrjOg5KZqN'
# Sentiment: Neutral
# Polarity: 0.0
#
# Row 233: '#COVIDUpdates: AP records as many as 7,813 new cases in the last 24 hours taking the tally to 88,671. 52 deaths wer… https://t.co/WRxXzhOFVA'
# Sentiment: Positive
# Polarity: 0.21212121212121213
#
# Row 234: 'Economies participating in the Asia-Pacific Economic Cooperation (#APEC) reaffirmed the prioritization of economic… https://t.co/fXIWpmUDNl'
# Sentiment: Positive
# Polarity: 0.2
#
# Row 235: 'WORLD #NEWS #TODAY SHORTENED FOR BUSY PEOPLE
# https://t.co/lcRKTCWIdy
#
# #politics #trump #money #wisdom #leadership… https://t.co/pPWyxba1SF'
# Sentiment: Positive
# Polarity: 0.1
#
# Row 236: '#APEC reaffirms #COVID19 economic recovery priorities, movement of essential goods https://t.co/sWRE9l9Fss'
# Sentiment: Positive
# Polarity: 0.1
#
# Row 237: 'July 25 #covid19 trend report for Dallas TX. DFW covid cases, hospitalizations, deaths, 7-day average.… https://t.co/RztOCAn19h'
# Sentiment: Neutral
# Polarity: 0.0
#
# Row 238: 'Cautious optimism? Arizona May be plateauing with #COVID19   Potential good news.  https://t.co/j20GOpHK04'
# Sentiment: Positive
# Polarity: 0.35
#
# Row 239: 'Want A #COVID19 Test? It’s Much Easier To Get In Wealthier, Whiter Neighborhoods #TestingWhileBlack https://t.co/vCdDRLHFEs'
# Sentiment: Positive
# Polarity: 0.2
#
# Row 240: '@jkenney @AdrianaLaGrange @RachelNotley @shoffmanAB sit in a room together &amp; find a solution please. Parents need y… https://t.co/xqaO5tG5UH'
# Sentiment: Neutral
# Polarity: 0.0
#
# Row 241: '@WalshFreedom @freddyatton I just realized, if trump &amp; @GOP were to win (God Forbid) and they finally stripped ACA-… https://t.co/gk8AS397q3'
# Sentiment: Positive
# Polarity: 0.4
#
# Row 242: 'Pleased to share our interesting results from worldwide survey of impact of #covid19 on bariatric surgery. Need rob… https://t.co/Xru8SrE3BK'
# Sentiment: Positive
# Polarity: 0.5
#
# Row 243: '🤔Remember when Trump told us that one day it would miraculously dissapear⁉️He was talking about your family, friend… https://t.co/mC4BnFqquE'
# Sentiment: Neutral
# Polarity: 0.0
#
# Row 244: 'Hon. Municipal Commissioner, Shravan Hardikar appeals to all patients recovered from #COVID19 to #donate their… https://t.co/DVfM8opTVv'
# Sentiment: Neutral
# Polarity: 0.0
#
# Row 245: '@NBCNews @TODAYshow 6 feet apart, no #masks, indoors. #COVID19 bad examples.
# How R U going 2 get the kids 2 wear em… https://t.co/EAD1loS5U7'
# Sentiment: Negative
# Polarity: -0.6999999999999998
#
# Row 246: 'The truth about #COVID19 has to be around here somewhere.
#
# #coronavirus update #SaturdayMorning #saturdayvibes https://t.co/7hiLER0fHc'
# Sentiment: Neutral
# Polarity: 0.0
#
# Row 247: '#coronavirusspain #COVID19 Warning! #Spain could once more be a death trap: second spike! #Catalonia #Barcelona has… https://t.co/AUFXd60ns1'
# Sentiment: Positive
# Polarity: 0.25
#
# Row 248: 'Three Cs is a term I hadn’t heard before. Good advice.
#
# #GoodAdvice
# #COVID19 https://t.co/ykSvJbILKP'
# Sentiment: Positive
# Polarity: 0.7
#
# Row 249: '#Delhi | 1,142 #COVID19 positive cases, 2,137 patients recovered/discharged/migrated and 29 deaths today. There are… https://t.co/Ty7BH1aVgO'
# Sentiment: Positive
# Polarity: 0.22727272727272727
#
# Row 250: 'Great to be with @ABC7Robert yesterday on @ABC7GMW #SocialDistancing #BBQ #COVID19 #COVID19 https://t.co/XSi0CvTSga'
# Sentiment: Positive
# Polarity: 0.8
#
# Row 251: 'Yes!
# #WakeUp #COVID19 #Fake #Plandemic #Exosomes #VirusTheory #5G is the real #Virus #SayNoToBillGates… https://t.co/fj9wHAH7IV'
# Sentiment: Negative
# Polarity: -0.15
#
# Row 252: 'We are pleased to announce the inclusion of the Virology Laboratory, University of Nigeria Teaching Hospital, Enugu… https://t.co/uxdPxiHN3J'
# Sentiment: Positive
# Polarity: 0.5
#
# Row 253: 'Why are apartment buildings exempt from the mask requirement? It makes no sense. There's probably 300 people in my… https://t.co/pS2nCZdPym'
# Sentiment: Neutral
# Polarity: 0.0
#
# Row 254: 'Great tips from our friends at @samhsagov! #COVID19 #InThisTogether https://t.co/BtsiHvnGB3'
# Sentiment: Positive
# Polarity: 1.0
#
# Row 255: 'ALERT: Parents decide whether to send kids back to school as
# coronavirus spreads faster than ever - Global Pandemic… https://t.co/4xlpmk4Zel'
# Sentiment: Neutral
# Polarity: 0.0
#
# Row 256: 'Does a football jersey count? First MD in the NFL, opting out to care for others. #MedBikini #COVID19 @Chiefs… https://t.co/z3JtqQG6HQ'
# Sentiment: Positive
# Polarity: 0.25
#
# Row 257: '“Since everything stopped because of the pandemic, I haven’t had any information from [LALA]. Nobody has contacted… https://t.co/FvHjSj6mMJ'
# ...
# Sentiment: Positive
# Polarity: 0.3
#
# Row 416: 'Yesterday #leftyTossers attacking #Boris for pointing out that obesity has a very negative effect on victims who ar… https://t.co/Pu1aiTKD9B'
# Sentiment: Negative
# Polarity: -0.39
#
# Row 417: 'Wit d econs meltdown  bcos of #COVID19 . Wit d battered state of d purchasing power of d citizens. Wt d rising pove… https://t.co/PI4q8PI0uY'
# Sentiment: Neutral
# Polarity: 0.0
#
# Row 418: 'Yestwrday, a friend’s brother died in Zimbabwe 🇿🇼, they called an ambulance at 2pm, it came at 8pm! #COVID19'
# Sentiment: Neutral
# Polarity: 0.0
#
# Row 419: '#AhmedabadRain
# Finally,
# It looks like rainy season has started now 😍,
# May it doesn’t brings hike in #covid19 infec… https://t.co/AceCeHERRk'
# Sentiment: Neutral
# Polarity: 0.0
#
# Row 420: 'Children are affected, infected and dying in Florida from Covid19.
# #ReopenSafely #ReopeningSchools #health #covid19… https://t.co/3XZPMne57z'
# Sentiment: Neutral
# Polarity: 0.0
#
# Row 421: 'History will not only account for the dead but also the wicked @GovRonDeSantis #COVID19 https://t.co/90MsXwkUss'
# Sentiment: Negative
# Polarity: -0.1
#
# Row 422: 'Ants may be pesky creatures, but it turns out we could learn a thing or two from them. @SophNaama writes about what… https://t.co/FzUG1KFhJL'
# Sentiment: Neutral
# Polarity: 0.0
#
# Row 423: 'This government was too slow to act, and even they now admit that. They followed and did not lead! It's very hard f… https://t.co/0ZlVcPpKkb'
# Sentiment: Negative
# Polarity: -0.3770833333333334
#
# Row 424: 'My observations after day 1 of mandatory face masks...I'm seeing a lot of "chin masks" and people walking around wi… https://t.co/jWdczSjAND'
# Sentiment: Neutral
# Polarity: 0.0
#
# Row 425: 'Delhi #COVID19 Update Jul 25
#
# New Cases 1142
# Total 129531
# July 43452 (33.54% of total)
#
# Deaths 29
# Total 3806
#
# Disch… https://t.co/62jsJh8TWH'
# Sentiment: Positive
# Polarity: 0.03409090909090909
#
# Row 426: 'Congratulations to Jeff Bezos
#
# The UK government has managed to make  shopping on the high street even less appeali… https://t.co/yGfUeXqVDH'
# Sentiment: Negative
# Polarity: -0.003333333333333327
#
# Row 427: 'Catalonia Spain reports 1,493 new #coronavirus cases #COVID19 👀👀'
# Sentiment: Positive
# Polarity: 0.13636363636363635
#
# Row 428: 'If you don’t have a mask.......just ask! We will provide one AND ask for a contribution to the West Midlands Air Am… https://t.co/rOTjxSvbT0'
# Sentiment: Neutral
# Polarity: 0.0
#
# Row 429: 'ALERT: Pregnant women at risk of death in Kenya's COVID-19
# curfew - Global Pandemic News | #Coronavirus #COVID19… https://t.co/MIklFXCtvj'
# Sentiment: Positive
# Polarity: 0.16666666666666666
#
# Row 430: '#COVID19 #COVIDー19 #coronavirus #BlackLivesMatter #satchat #ptech #weareptech https://t.co/2tCw7OEqpV An open dialo… https://t.co/CdQNTeh7D1'
# Sentiment: Neutral
# Polarity: 0.0
#
# Row 431: 'Check us out on Spotify as well
# 🙌🎶👑🔊🔥👇👇👇👇
# https://t.co/v2XKBfaTfj
#
# #GospelHouse 🎶👑🔊💯
# #GodGotThis ❤🙌🔥🔥🔥… https://t.co/oeIUQVc6gR'
# Sentiment: Neutral
# Polarity: 0.0
#
# Row 432: 'could double as a #COVID19 vaccine delivery mechanism @BorisJohnson  @MattHancock @pritipatel https://t.co/hM83eKV2LF'
# Sentiment: Neutral
# Polarity: 0.0
#
# Row 433: 'Help slow the spread of #COVID19 and identify at risk cases sooner by self-reporting your symptoms daily, even if y… https://t.co/KSyVttdgqo'
# Sentiment: Negative
# Polarity: -0.15000000000000002
#
# Row 434: '@OpIndia_com #how #heir @joker @laluprasadrjd @yadavtejashwi #have #little #knowledge @mygovindia @who #thinks… https://t.co/9GyojXmCS7'
# Sentiment: Negative
# Polarity: -0.1875
#
# Row 435: 'Sign the Alert to Stop Deadly Mass Killing of #Animals in #University Labs Due to #COVID19 https://t.co/tzaxAeeS14'
# Sentiment: Negative
# Polarity: -0.1625
#
# Row 436: '@jennfranconews @realDonaldTrump Each of you should look not only to your own interests, but also to the interests… https://t.co/g3bYHLyXd4'
# Sentiment: Positive
# Polarity: 0.3
#
# Row 437: 'The latest Islam and Islamism! https://t.co/1Gx3WUOc9r #berkleyforum #covid19'
# Sentiment: Positive
# Polarity: 0.625
#
# Row 438: '#Hope #USA #Trump vilifying #USPS &amp; #Amazon while (Republicans own premium stock) catering to them by #Postmaster w… https://t.co/wznVS6kWKo'
# Sentiment: Positive
# Polarity: 0.6
#
# Row 439: '#AndhraPradesh reports 7,813 new #COVID19 cases on Saturday as the tally goes up to 88,671. The death toll increase… https://t.co/Pk3YJjwX19'
# Sentiment: Positive
# Polarity: 0.13636363636363635
#
# Row 440: '#Coronavirus in #Andorra: There is a total of 52 confirmed deaths from #COVID19.'
# Sentiment: Positive
# Polarity: 0.2
#
# Row 441: '@fordnation
# Please don't go in like a bunch of storm troopers !
# The migrant workers are afraid of being deported so… https://t.co/w0D37rCtza'
# Sentiment: Negative
# Polarity: -0.6
#
# Row 442: 'Wear a face cover or pay £100 fine. New laws imposed in London #covid19 #London ''. Lol. I Chose to cover it up. https://t.co/AO2qMQ1Vln'
# Sentiment: Positive
# Polarity: 0.451010101010101
#
# Row 443: '#COVIDUpdates: AP records as many as 7,813 new cases in the last 24 hours taking the tally to 88,671. 52 deaths wer… https://t.co/doN2jrcaTe'
# Sentiment: Positive
# Polarity: 0.21212121212121213
#
# Row 444: 'Remember when #Drumpf said #TexasIsHeeling?? Well, they're getting screwed several times over today!! Not to mentio… https://t.co/B5PLXiC3Gh'
# Sentiment: Neutral
# Polarity: 0.0
#
# Row 445: 'Ringway, Preston (14th May 2020 and 24th July 2020)
# I will be releasing another video this weekend from the past co… https://t.co/X98cNByTW3'
# Sentiment: Negative
# Polarity: -0.25
#
# Row 446: 'The statistics in the #pic gives info that #Assam is performing better than #Odisha in their fight against #COVID19… https://t.co/rdrtsDfWyF'
# Sentiment: Positive
# Polarity: 0.5
#
# Row 447: ''Not what we should be doing': Few masks, no social distancing at crowded Falls attractions | CBC News https://t.co/TFwjEhdLHI #COVID19'
# Sentiment: Negative
# Polarity: -0.10833333333333334
#
# Row 448: 'If you think I’m buying any of these rumours of us being locked down or restricted for up to 2 years, forget it. It… https://t.co/aEQZaqs79U'
# Sentiment: Negative
# Polarity: -0.15555555555555559
#
# Row 449: '@realDonaldTrump Remember the #WorstPresidentInHistory #trumpdeathtoll147K 4.2 Million cases of #COVID19 Millions U… https://t.co/tv0DXaS2nJ'
# Sentiment: Neutral
# Polarity: 0.0
#
# Row 450: 'With increased testing of samples for Covid-19, the fatality rate has significantly dropped to 2.35% on Saturday an… https://t.co/48x8cQ6sxA'
# Sentiment: Positive
# Polarity: 0.375
#
# Row 451: 'CDC changes COVID-19 guidance on how long people need to be isolated https://t.co/LqEQKBBQAN via @nbcnews #COVID19 #theyhavenoidea'
# Sentiment: Negative
# Polarity: -0.05
#
# Row 452: '👀 A plea to #mask wearers to read this as THIS is why many #NoMasks don’t want to blindly follow “govt” edicts on… https://t.co/uQWjZyPQ7j'
# Sentiment: Neutral
# Polarity: 0.0
#
# Row 453: '#MP CM #ShivrajSinghChouhan tested positive for #COVID19 . There's been news that bcoz of him many ministers as wel… https://t.co/c1ia1QsqXQ'
# Sentiment: Positive
# Polarity: 0.36363636363636365
#
# Row 454: '(6) We never rise beyond the level of our knowledge. This is why you must keep acquiring new and helpful informatio… https://t.co/Z4EDRcuMTU'
# Sentiment: Positive
# Polarity: 0.13636363636363635
#
# Row 455: 'Two students tested positive for coronavirus after taking the ACT at an Oklahoma high school… https://t.co/DRNa3Uq3th'
# Sentiment: Positive
# Polarity: 0.19363636363636363
#
# Row 456: 'Sending the science deniers home to their fellow MAGATs.  #BlueWave2020 #COVID19 https://t.co/BKMbdjClDk'
# Sentiment: Neutral
# Polarity: 0.0
#
# Row 457: 'Home-made cloth face masks likely need a minimum of two layers, and preferably three, to prevent the dispersal of v… https://t.co/PssY9MisDQ'
# Sentiment: Neutral
# Polarity: 0.0
#
# Row 458: '@Die_Diktatur @FatEmperor @WHO 2009 was just the rehearsal for #COVID19'
# Sentiment: Neutral
# Polarity: 0.0
#
# Row 459: '#AndhraPradesh
#
# Andhra Pradesh registered single-day spike of 7,813 #COVID19 positive cases &amp; 52 deaths in last 24… https://t.co/2xK87RJYnF'
# Sentiment: Positive
# Polarity: 0.11363636363636363
#
# Row 460: 'How well are you dealing with the COVID-19 outbreak? This survey developed by psychologists from around the world p… https://t.co/N3l6dIa4O9'
# Sentiment: Positive
# Polarity: 0.1
#
# Row 461: 'The thing about being #LightSkinned is that every bruise on your body can be seen from Mars 🌝plus the fact that you… https://t.co/MwqNMipANn'
# Sentiment: Neutral
# Polarity: 0.0
#
# Row 462: 'Actor @VishalKOfficial and his father Mr.G.K.Reddy tested positive for #Covid19 15/20 days back..
#
# While #Vishal 's… https://t.co/yXdPgtkW92'
# Sentiment: Positive
# Polarity: 0.11363636363636363
#
# Row 463: '. @PawanKalyan about resuming movie shootings in his latest interview.
# #Covid19 #Janasena #Powerstar #VakeelSaab https://t.co/bpalIFxA6F'
# Sentiment: Positive
# Polarity: 0.5
#
# Row 464: 'Another WWE employee has contracted COVID-19
#
# Via @PWCDeez
#
# #WWE #WrestleMania #COVID19 #Coronavirus
#
# https://t.co/6sxCU0hn7a'
# Sentiment: Neutral
# Polarity: 0.0
#
# Row 465: 'Thats What i got In This Productive Quarantine ,  After a Hard Assignments and Quizzes . #Productive  #COVID19… https://t.co/B7mEqHTPHm'
# Sentiment: Negative
# Polarity: -0.2916666666666667
#
# Row 466: 'In order to help people opting for Home Isolation, TriBeCa Care has come up with a remote monitoring package.  Cont… https://t.co/XW2uPlBAxj'
# Sentiment: Negative
# Polarity: -0.1
#
# Row 467: '#COVID19 : Restriction extended in #kupwara till 3 August.
# #CoronaVirusUpdate #FightAgainstCOVID19 #PANDAMIC https://t.co/XeP0c0LBRD'
# Sentiment: Neutral
# Polarity: 0.0
#
# Row 468: '@NBCNews @gtconway3d and... can the press knock it off with this whole “change of tone” this week from Trump. It’s… https://t.co/7Bgj4C9atH'
# Sentiment: Positive
# Polarity: 0.2
#
# Row 469: 'A big thank you to the team Cenit College in Nass and their ongoing support for our #ADR #Exams. Due to #COVID19 re… https://t.co/SJmuYI5DNR'
# Sentiment: Negative
# Polarity: -0.0625
#
# Row 470: 'New Personal View: Need for sustainable biobanking networks for #COVID19 and other diseases of epidemic potential https://t.co/jmYKciZOju'
# Sentiment: Positive
# Polarity: 0.0028409090909090884
#
# Row 471: '#COVID19 has worsened an already dire opioid crisis. There are fewer social supports, people battling addictions mu… https://t.co/WIN1DZkoYn'
# Sentiment: Positive
# Polarity: 0.03333333333333333
#
# Row 472: 'Passengers cheer as ‘Karen’ is kicked off flight for refusing to wear mask
# #airlines
# #coronavirus
# #covid19
# #Mask  https://t.co/3VimRsfAUb'
# Sentiment: Neutral
# Polarity: 0.0
#
# Row 473: '🔴Corona Alert |
# Four arrivals from Chennai tested positive for Covid-19 raising the total in Sri Lanka to 2,768.… https://t.co/AwDjGiZvDT'
# Sentiment: Positive
# Polarity: 0.11363636363636363
#
# Row 474: 'Oh for fvck’s sake @CNN @sarahcwestwood STOP WITH THE BS. #trump has not changed his tone. So @FoxNews.
# #CNN weeke… https://t.co/4DVBg0cCqF'
# Sentiment: Neutral
# Polarity: 0.0
#
# Row 475: 'Teachers dealing with gettin they students in virtual class who have Parents that are just no help at all. So eithe… https://t.co/1xNXd2wH2t'
# Sentiment: Neutral
# Polarity: 0.0
#
# Row 476: '@NYCAudubon #Audubon #SaturdayMorning #SaturdayVibes #COVID19 #SaturdayThoughts #SaturdayMotivation #free shipping… https://t.co/VUTtHfSyPo'
# Sentiment: Positive
# Polarity: 0.4
#
# Row 477: 'The #OrangeBaboon wants to make sure we have over 150K dead from #COVID19 before the end of July!
#
# 7/24: 148490 dea… https://t.co/cOVtyFoRrL'
# Sentiment: Positive
# Polarity: 0.15
#
# Row 478: 'How did America go from
# the land of the free and home of the brave
# to
# the land of the acquiescent and home of the f… https://t.co/EoRJn52zBv'
# Sentiment: Positive
# Polarity: 0.6000000000000001
#
# Row 479: 'https://t.co/v4w6cLyHhu
#
# RFK Jr soars. Phenomenal read about the LACK of scientific testing behind #vaccine development. #COVID19'
# Sentiment: Positive
# Polarity: 0.04999999999999999
#
# Row 480: 'Together as One! #Covid19 #EconomicRecovery https://t.co/DwABLnFpjR'
# Sentiment: Neutral
# Polarity: 0.0
#
# Row 481: 'We've progressed to the point that we're joking about #COVID19 . That's good...now if we could just get some sort o… https://t.co/AKDfTtpsFY'
# Sentiment: Neutral
# Polarity: 0.0
#
# Row 482: '@forwardarc @realDonaldTrump @VP If the U.S. doesn’t lock down, we’re stupid, and will reap what we sowed.
# And I c… https://t.co/7hwD0gcNOt'
# Sentiment: Negative
# Polarity: -0.47777777777777775
#
# Row 483: 'so lets pack'em all into schools in late summer/fall, big mistake for now as young are always a major disease vecto… https://t.co/uCNLTAsTnU'
# Sentiment: Negative
# Polarity: -0.034374999999999996
#
# Row 484: '@funder Cannot imagine ANY #American in a right state of mind ever voting for the LUMP OF MASS unless they're membe… https://t.co/3AbFjr96H8'
# Sentiment: Positive
# Polarity: 0.14285714285714285
#
# Row 485: 'If schools reopen the spread of #COVID19 will be on a biblical scale.'
# Sentiment: Neutral
# Polarity: 0.0
#
# Row 486: 'Hello #dorathians. Let's hit 1k followers on Twitter.  Kindly retweet and follow 😘
# https://t.co/Jp8aRjoEE3… https://t.co/ADPR7A7qCN'
# Sentiment: Positive
# Polarity: 0.6
#
# Row 487: 'With #Coimbatore district administration announcing complete #lockdown from 5 pm on Saturday till 6 am on Monday, h… https://t.co/T66nLKWg9M'
# Sentiment: Positive
# Polarity: 0.1
#
# Row 488: '@realDonaldTrump #TrumpDeathToll148K 4.2 Million cases of #COVID19 Millions Unemployed! #TrumpPandemicFailure… https://t.co/FbcBToXKQC'
# Sentiment: Neutral
# Polarity: 0.0
#
# Row 489: 'Cheap #virus-killing spray that costs pennies could end Britain's #coronavirus, #COVID19 nightmare https://t.co/LSVcYqIweS'
# Sentiment: Positive
# Polarity: 0.4
#
# Row 490: 'One of the roles these survelliance team play in the community is to respond to and also support women and girls ex… https://t.co/lXtL03iXUO'
# Sentiment: Neutral
# Polarity: 0.0
#
# Row 491: '#Hurricane may hit area with major #COVID19 spread &amp;  full hospitals. This is why we need
#
# https://t.co/nLfpY1vEvZ… https://t.co/DulqthAtyT'
# Sentiment: Positive
# Polarity: 0.20625
#
# Row 492: 'Day 31: #FreePalestine
# Palestinians are still in danger of #COVID19. #PalestiniansLivesMatter #EndApartheidNow… https://t.co/chDHeKuOgE'
# Sentiment: Neutral
# Polarity: 0.0
#
# Row 493: 'SRV Group of Hospitals is dedicated in making neighborhood healthy.
# To book an appointmentr our SRV experts call 86… https://t.co/QdaKcO06JW'
# Sentiment: Positive
# Polarity: 0.5
#
# Row 494: '293 new cases and 3 new deaths in Uzbekistan
#
# [13:11 GMT] #coronavirus #CoronaVirusUpdate #COVID19 #CoronavirusPandemic'
# Sentiment: Positive
# Polarity: 0.13636363636363635
#
# Row 495: '@DonaldJTrumpJr 145k million dead from #COVID19 over 40 million unemployed GFY'
# Sentiment: Negative
# Polarity: -0.2
#
# Row 496: 'As Somalia heads to political campaign and later elections, any political instability at this time will reverse any… https://t.co/fZuMSygdR3'
# Sentiment: Neutral
# Polarity: 0.0
#
# Row 497: '@jjauthor Can someone give this twirp and his family #COVID19 please and thank you.'
# Sentiment: Neutral
# Polarity: 0.0
#
# Row 498: 'The @UN is helping families use the opportunity to teach young people about global challenges, including not only t… https://t.co/blbaeTj90J'
# Sentiment: Positive
# Polarity: 0.03333333333333333
#
# Row 499: 'Spike in U.S. Cases Far Outpaces Testing Expansion
#  https://t.co/HqB3P5aIcS
# #COVID19 https://t.co/HG1V3iTSwd'
# Sentiment: Positive
# Polarity: 0.1
#
# Row 500: 'ALERT: Right-Wing People ‘Least Likely To Wear Face Masks’ - Global Pandemic News | #Coronavirus #COVID19 #Protests… https://t.co/3aeXQVuHy1'
# Sentiment: Negative
# Polarity: -0.09999999999999999
# Summarize dataset:   0%|          | 0/5 [00:00<?, ?it/s]
# Generate report structure:   0%|          | 0/1 [00:00<?, ?it/s]
# Render HTML:   0%|          | 0/1 [00:00<?, ?it/s]
# Export report to file:   0%|          | 0/1 [00:00<?, ?it/s]
# Summarize dataset:   0%|          | 0/5 [00:00<?, ?it/s]
# Generate report structure:   0%|          | 0/1 [00:00<?, ?it/s]
# Render HTML:   0%|          | 0/1 [00:00<?, ?it/s]
# Export report to file:   0%|          | 0/1 [00:00<?, ?it/s]

# %%
positive_count = len(df_positive_sentiments)
negative_count = len(df_negative_sentiments)
# Assuming you have already calculated positive_count and negative_count as the counts of positive and negative sentiments
# Calculate the count of the opposite sentiment
total_count = 500
neutral_count = total_count - (positive_count + negative_count)

# Create data for the pie chart
sentiments = ['Positive', 'Negative', 'Neutral']
counts = [positive_count, negative_count, neutral_count]
colors = ['green', 'red', 'gray']

# Create a pie chart
plt.figure(figsize=(8, 8))
plt.pie(counts, labels=sentiments, colors=colors, autopct='%1.1f%%', startangle=140)
plt.title('Sentiment Distribution (Total Count: 500)')
plt.axis('equal')  # Equal aspect ratio ensures that pie is drawn as a circle.
plt.show()

# %%
import pandas as pd
import matplotlib.pyplot as plt

# Load the CSV dataset (replace 'covid19_tweets.csv' with your file path)
df = pd.read_csv('covid19_tweets.csv')

# Extract the tweet counts for each user
tweet_counts = df['user_name'].value_counts()

# Select the top 10 people with the most tweets
top_10_people = tweet_counts.head(10)

# Display the list of top 10 people by tweet count
print("Top 10 People by Tweet Count:")
print(top_10_people)

# Create a vertical bar chart for the top 10 people
plt.figure(figsize=(6, 2))
plt.bar(top_10_people.index, top_10_people.values, color='skyblue')
plt.xticks(rotation=90)  # Rotate x-axis labels for better readability
plt.xlabel('User Name')
plt.ylabel('Tweet Count')
plt.title('Top 10 People by Tweet Count')
plt.show()
# Out:
# Top 10 People by Tweet Count:
# GlobalPandemic.NET        679
# Coronavirus Updates       625
# covidnews.ch              402
# Open Letters              390
# Blood Donors India        282
# Hindustan Times           280
# IAM Platform              266
# Paperbirds_Coronavirus    259
# IANS Tweets               244
# ANI                       233
# Name: user_name, dtype: int64

# %%
import pandas as pd

# Load data
data = pd.read_csv("covid19_tweets.csv", 
                   dtype={'Country/Region': str,
                          'Province/State': str,
                          'Latitude': float,
                          'Longitude': float,
                          'Confirmed': float,
                          'Recovered': float,
                          'Deaths': float})

# Rename columns
data = data.rename(columns={"Country/Region": "Country", "Province/State": "State"})

# Load tweet data
tweets = pd.read_csv("covid19_tweets.csv",
                     dtype={'user_name': str,
                            'user_location': str,
                            'user_description': str,
                            'user_followers': float,
                            'user_friends': float,
                            'user_favourites': float,
                            'user_verified': bool,
                            'text': str,
                            'hashtags': str,
                            'source': str,
                            'is_retweet': bool})

# Convert date columns to datetime
tweets['user_created'] = pd.to_datetime(tweets['user_created'])
tweets['date'] = pd.to_datetime(tweets['date'])

# Inspect data
print("Data Table:")
print(data.head(5))

# Inspect tweet data
print("\nTweet Data Table:")
print(tweets.head(2))
# Out:
# Data Table:
#          user_name         user_location  \
# 0           ᏉᎥ☻լꂅϮ            astroworld
# 1    Tom Basile 🇺🇸          New York, NY
# 2  Time4fisticuffs      Pewee Valley, KY
# 3      ethel mertz  Stuck in the Middle
# 4         DIPR-J&K     Jammu and Kashmir
#
#                                     user_description         user_created  \
# 0  wednesday addams as a disney princess keepin i...  2017-05-26 05:46:42
# 1  Husband, Father, Columnist & Commentator. Auth...  2009-04-16 20:06:23
# 2  #Christian #Catholic #Conservative #Reagan #Re...  2009-02-28 18:57:41
# 3  #Browns #Indians #ClevelandProud #[]_[] #Cavs ...  2019-03-07 01:45:06
# 4  🖊️Official Twitter handle of Department of Inf...  2017-02-12 06:45:15
#
#    user_followers  user_friends  user_favourites  user_verified  \
# 0             624           950            18775          False
# 1            2253          1677               24           True
# 2            9275          9525             7254          False
# 3             197           987             1488          False
# 4          101009           168              101          False
#
#                   date                                               text  \
# 0  2020-07-25 12:27:21  If I smelled the scent of hand sanitizers toda...
# 1  2020-07-25 12:27:17  Hey @Yankees @YankeesPR and @MLB - wouldn't it...
# 2  2020-07-25 12:27:14  @diane3443 @wdunlap @realDonaldTrump Trump nev...
# 3  2020-07-25 12:27:10  @brookbanktv The one gift #COVID19 has give me...
# 4  2020-07-25 12:27:08  25 July : Media Bulletin on Novel #CoronaVirus...
#
#                             hashtags               source  is_retweet
# 0                                NaN   Twitter for iPhone       False
# 1                                NaN  Twitter for Android       False
# 2                        ['COVID19']  Twitter for Android       False
# 3                        ['COVID19']   Twitter for iPhone       False
# 4  ['CoronaVirusUpdates', 'COVID19']  Twitter for Android       False
#
# Tweet Data Table:
#        user_name user_location  \
# 0         ᏉᎥ☻լꂅϮ    astroworld
# 1  Tom Basile 🇺🇸  New York, NY
#
#                                     user_description        user_created  \
# 0  wednesday addams as a disney princess keepin i... 2017-05-26 05:46:42
# 1  Husband, Father, Columnist & Commentator. Auth... 2009-04-16 20:06:23
#
#    user_followers  user_friends  user_favourites  user_verified  \
# 0           624.0         950.0          18775.0          False
# 1          2253.0        1677.0             24.0           True
#
#                  date                                               text  \
# 0 2020-07-25 12:27:21  If I smelled the scent of hand sanitizers toda...
# 1 2020-07-25 12:27:17  Hey @Yankees @YankeesPR and @MLB - wouldn't it...
#
#   hashtags               source  is_retweet
# 0      NaN   Twitter for iPhone       False
# 1      NaN  Twitter for Android       False

# %%
import pandas as pd
import matplotlib.pyplot as plt

# Load the CSV dataset (replace 'covid19_tweets.csv' with your file path)
df = pd.read_csv('covid19_tweets.csv')

# Assuming you have a column in your dataset that contains user locations, let's call it 'user_location'
user_location_column = 'user_location'  # Replace 'user_location' with the actual column name

# Extract all user locations
user_locations_all = df[user_location_column]

# Get the top 15 unique user locations and their frequencies
top_15_user_locations = user_locations_all.value_counts().head(15)

# Create a DataFrame to store the data
top_user_locations_df = pd.DataFrame({'User Location': top_15_user_locations.index, 'Frequency': top_15_user_locations.values})

# Create a bar chart for the top 15 user locations
plt.figure(figsize=(10, 6))
plt.barh(top_user_locations_df['User Location'], top_user_locations_df['Frequency'], color='skyblue')
plt.xlabel('Frequency')
plt.ylabel('User Location')
plt.title('Top 15 User Locations by Frequency')
plt.gca().invert_yaxis()  # Invert the y-axis to display the top location at the top
plt.show()

# %%
import pandas as pd
import matplotlib.pyplot as plt

# Set the figure size
plt.rcParams['figure.figsize'] = (14, 6)

# Assuming you have a DataFrame called 'tweets' with a column 'date'

# Convert the 'date' column to datetime
tweets['date'] = pd.to_datetime(tweets['date'])

# Group by date and count the number of tweets
tweet_counts = tweets.groupby('date').size().reset_index(name='n')

# Create a line plot
plt.plot(tweet_counts['date'], tweet_counts['n'], linewidth=1.5, color='blue')

# Set the plot limits to not clip data points
plt.xlim(tweet_counts['date'].min(), tweet_counts['date'].max())

# Customize the plot appearance (you can define 'my_theme' and 'my_colors' separately)
plt.title("Number of Tweets in Time", fontsize=16)
plt.xlabel("Date", fontsize=14)
plt.ylabel("Frequency", fontsize=14)

# Remove x-axis title
plt.gca().set_xlabel('')

# Show the plot
plt.show()
